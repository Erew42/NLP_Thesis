# %%
# Cell 1
# !pip install --upgrade polars
# !pip install pyspark
# !pip install "git+https://github.com/Erew42/NLP_Thesis.git@main"
# !pip install polars
# !pip install pyspark
# Out:
# Collecting git+https://github.com/Erew42/NLP_Thesis.git@main
#   Cloning https://github.com/Erew42/NLP_Thesis.git (to revision main) to /tmp/pip-req-build-4idomdpz
#   Running command git clone --filter=blob:none --quiet https://github.com/Erew42/NLP_Thesis.git /tmp/pip-req-build-4idomdpz
#   Resolved https://github.com/Erew42/NLP_Thesis.git to commit a16abfce335fb2bfb56e4ffdaab847b518ff7bb3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting polars>=1.0.0 (from thesis_pkg==0.1.0)
#   Downloading polars-1.37.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from thesis_pkg==0.1.0) (2.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from thesis_pkg==0.1.0) (22.0.0)
# Collecting polars-runtime-32==1.37.1 (from polars>=1.0.0->thesis_pkg==0.1.0)
#   Downloading polars_runtime_32-1.37.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->thesis_pkg==0.1.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->thesis_pkg==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->thesis_pkg==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->thesis_pkg==0.1.0) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->thesis_pkg==0.1.0) (1.17.0)
# Downloading polars-1.37.1-py3-none-any.whl (805 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.7/805.7 kB 26.3 MB/s eta 0:00:00
# Downloading polars_runtime_32-1.37.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (45.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 MB 101.1 MB/s eta 0:00:00
# Building wheels for collected packages: thesis_pkg
#   Building wheel for thesis_pkg (pyproject.toml) ... done
#   Created wheel for thesis_pkg: filename=thesis_pkg-0.1.0-py3-none-any.whl size=39583 sha256=9a7b2d1dbfd4048b6edad5200d003e4746a1bb635cea9ef1be3c023bcc916c1b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b_wvgb5m/wheels/2e/cf/d9/da9e5ac1f7c998d0e8b0344c05c481da8d5177f232d69b1537
# Successfully built thesis_pkg
# Installing collected packages: polars-runtime-32, polars, thesis_pkg
# Successfully installed polars-1.37.1 polars-runtime-32-1.37.1 thesis_pkg-0.1.0
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (1.37.1)
# Requirement already satisfied: polars-runtime-32==1.37.1 in /usr/local/lib/python3.12/dist-packages (from polars) (1.37.1)
# Collecting pyspark
#   Downloading pyspark-4.1.1.tar.gz (455.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 MB 8.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting py4j<0.10.9.10,>=0.10.9.7 (from pyspark)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.0/203.0 kB 24.8 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (pyproject.toml) ... done
#   Created wheel for pyspark: filename=pyspark-4.1.1-py2.py3-none-any.whl size=456008707 sha256=380037425314be1f1b30f9aa7d2c7b94e38fe78f3ee8d605ad281056efdce6b6
#   Stored in directory: /root/.cache/pip/wheels/f4/ca/ea/203f40b3e935bbf99bee851c2f4a87d22996ab8212d367ce58
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.9 pyspark-4.1.1

# %%
# Cell 2

import pandas as pd
import numpy as np
from pathlib import Path
import polars as pl
import gc
from pyspark import sql
import datetime as dt
import os
import polars.selectors as cs

# %%
# Cell 3
try:
    from google.colab import drive
    drive.mount('/content/drive')
    print("Google Drive mounted successfully.")
except ImportError:
    print("Not in Colab environment. Assuming local file access.")
    # If not in Colab, BASE_DIR should point to a local path
    # For this script, we'll assume the /content/drive path works
# Out:
# Mounted at /content/drive
# Google Drive mounted successfully.

# %%
# Cell 4

# --- Set Global Display Options for Polars ---

# Set the maximum number of rows to display for any DataFrame/LazyFrame print
# For example, to show a maximum of 15 rows:
pl.Config.set_tbl_rows(50)

# Optionally, you can also set the maximum number of columns if needed:
pl.Config.set_tbl_cols(50)
# Out:
# polars.config.Config

# %%
# Cell 5

# load all files as polars lazyframes and print column names
from pathlib import Path
import shutil
import polars as pl

# ---- CONFIG ----
BASE_DIR = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/parquet_data/')
BASE_DIR2 = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/')
TARGET_FOLDERS = [
    'documents-export-2025-3-19',
    'documents-export-2025-3-19(1)',
    'documents-export-2025-3-19(2)',
    'derived_data',
]

def schema_columns(parquet_path: Path) -> list[str]:
    # uses lazy scan -> reads only metadata to get the schema
    lf = pl.scan_parquet(parquet_path)
    return list(lf.schema.keys())
    # or shorter:
    # return list(pl.scan_parquet(parquet_path).schema.keys())



for sub in TARGET_FOLDERS:
    if sub == 'derived_data':
      BASE_DIR_temp = BASE_DIR2
    else:
      BASE_DIR_temp = BASE_DIR

    folder = BASE_DIR_temp / sub

    if not folder.exists():
        print(f"[warn] missing folder: {folder}")
        continue

    for p in folder.rglob('*.parquet'):
        # 1) Print columns
        try:
            cols = schema_columns(p)
            print(f"- {p.relative_to(BASE_DIR_temp)}")
            print(f"  columns ({len(cols)}): {cols}")
        except Exception as e:
            print(f"! {p.relative_to(BASE_DIR_temp)} -> schema read failed: {e}")
# Out:
# /tmp/ipython-input-1618946452.py:21: PerformanceWarning: Resolving the schema of a LazyFrame is a potentially expensive operation. Use `LazyFrame.collect_schema()` to get the schema without this warning.
#   return list(lf.schema.keys())
# - documents-export-2025-3-19/indexdatadaily.parquet
#   columns (14): ['KYGVKEYX', 'DATADATE', 'DVPSXD', 'NEWNUM', 'OLDNUM', 'PRCCD', 'PRCCDDIV', 'PRCHD', 'PRCLD', 'SPIHI', 'SPILO', 'SPINUMN', 'SPINUMO', 'SPIPRC']
# - documents-export-2025-3-19/balancesheetquarterly.parquet
#   columns (351): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'ACCOQ', 'ACCOQ_DC', 'ACOMINCQ', 'ACOMINCQ_DC', 'ACOQ', 'ACOQ_DC', 'ACTQ', 'ALTOQ', 'ANCQ', 'ANOQ', 'ANOQ_DC', 'AOCIDERGLQ', 'AOCIDERGLQ_DC', 'AOCIDERGLQ_FN', 'AOCIOTHERQ', 'AOCIPENQ', 'AOCIPENQ_DC', 'AOCIPENQ_FN', 'AOCISECGLQ', 'AOCISECGLQ_DC', 'AOL2Q', 'AOL2Q_DC', 'AOQ', 'AOQ_DC', 'APQ', 'APQ_DC', 'APQ_FN1', 'AQPL1Q', 'AQPL1Q_DC', 'ATQ', 'ATQ_DC', 'ATQ_FN1', 'AUL3Q', 'AUL3Q_DC', 'BILLEXCEQ', 'CAPR1Q', 'CAPR1Q_DC', 'CAPR1Q_FN1', 'CAPR2Q', 'CAPR3Q', 'CAPR3Q_DC', 'CAPR3Q_FN1', 'CAPRTQ_FN', 'CAPSFTQ', 'CAPSFTQ_DC', 'CAPSQ', 'CAPSQ_DC', 'CAPSQ_FN1', 'CAQ', 'CAQ_DC', 'CEIEXBILLQ', 'CEIEXBILLQ_FN', 'CEQQ', 'CEQQ_DC', 'CHEQ', 'CHEQ_DC', 'CHQ', 'CHQ_DC', 'CSHIQ', 'CSHIQ_DC', 'CSHOPQ', 'CSHOPQ_DC', 'CSHOQ', 'CSHOQ_DC', 'CSHOQ_FN', 'CSTKQ', 'CSTKQ_DC', 'CSTKQ_FN1', 'DCOMQ', 'DCOMQ_DC', 'DERACQ', 'DERACQ_DC', 'DERALTQ', 'DERALTQ_DC', 'DERLCQ', 'DERLCQ_DC', 'DERLLTQ', 'DERLLTQ_DC', 'DLCQ', 'DLCQ_DC', 'DLCQ_FN1', 'DLTTQ', 'DLTTQ_DC', 'DLTTQ_FN1', 'DPACREQ', 'DPACTQ', 'DPACTQ_DC', 'DPACTQ_FN1', 'DPTCQ', 'DPTCQ_DC', 'DRCQ', 'DRCQ_DC', 'DRLTQ', 'DRLTQ_DC', 'ESOPCTQ', 'ESOPCTQ_DC', 'ESOPNRQ', 'ESOPRQ', 'ESOPTQ', 'ESOPTQ_FN', 'FINACOQ', 'FINACOQ_DC', 'FINAOQ', 'FINAOQ_DC', 'FINCHQ', 'FINCHQ_DC', 'FINDLCQ', 'FINDLCQ_DC', 'FINDLTQ', 'FINDLTQ_DC', 'FINDLTQ_FN', 'FINIVSTQ', 'FINIVSTQ_DC', 'FINLCOQ', 'FINLCOQ_DC', 'FINLTOQ', 'FINLTOQ_DC', 'FINNPQ', 'FINNPQ_DC', 'FINRECCQ', 'FINRECCQ_DC', 'FINRECLTQ', 'FINRECLTQ_DC', 'GDWLQ', 'GDWLQ_DC', 'ICAPTQ', 'ICAPTQ_DC', 'ICAPTQ_FN', 'INTACCQ', 'INTACCQ_DC', 'INTANOQ', 'INTANOQ_DC', 'INTANQ', 'INTANQ_DC', 'INVFGQ', 'INVFGQ_DC', 'INVOQ', 'INVRMQ', 'INVRMQ_DC', 'INVTQ', 'INVTQ_DC', 'INVWIPQ', 'INVWIPQ_DC', 'ISTQ', 'IVAEQQ', 'IVAEQQ_DC', 'IVAOQ', 'IVAOQ_DC', 'IVLTQ', 'IVLTQ_DC', 'IVSTQ', 'IVSTQ_DC', 'LCOQ', 'LCOQ_DC', 'LCTQ', 'LLTQ', 'LNOQ', 'LNOQ_DC', 'LOL2Q', 'LOL2Q_DC', 'LOQ', 'LOQ_DC', 'LOXDRQ', 'LQPL1Q', 'LQPL1Q_DC', 'LSEQ', 'LSEQ_DC', 'LSEQ_FN1', 'LTMIBQ', 'LTQ', 'LUL3Q', 'LUL3Q_DC', 'MIBNQ', 'MIBNQ_DC', 'MIBQ', 'MIBQ_DC', 'MIBTQ', 'MIBTQ_DC', 'MSAQ', 'MSAQ_DC', 'MSAQ_FN', 'NCOQ', 'NCOQ_DC', 'NPATQ', 'NPATQ_DC', 'NPQ', 'OBKQ', 'OPTDRQ', 'OPTDRQ_FN', 'OPTFVGRQ', 'OPTFVGRQ_FN', 'OPTLIFEQ', 'OPTLIFEQ_FN', 'OPTRFRQ', 'OPTRFRQ_FN', 'OPTVOLQ', 'OPTVOLQ_FN', 'PNRSHOQ', 'PNRSHOQ_DC', 'PNRSHOQ_FN', 'PPEGTQ', 'PPEGTQ_DC', 'PPENTQ', 'PPENTQ_DC', 'PRCRAQ', 'PRCRAQ_FN', 'PRSHOQ', 'PRSHOQ_DC', 'PRSHOQ_FN', 'PSTKNQ', 'PSTKNQ_DC', 'PSTKQ', 'PSTKQ_DC', 'PSTKRQ', 'PSTKRQ_DC', 'RECDQ', 'RECDQ_DC', 'RECTAQ', 'RECTAQ_DC', 'RECTAQ_FN', 'RECTOQ', 'RECTOQ_DC', 'RECTQ', 'RECTQ_DC', 'RECTRQ', 'RECTRQ_DC', 'RECUBQ', 'REQ', 'REQ_DC', 'REQ_FN1', 'RETQ', 'REUNAQ', 'REUNAQ_DC', 'REUNAQ_FN', 'RLLQ', 'RSTCHELTQ', 'RSTCHELTQ_DC', 'RSTCHEQ', 'RSTCHEQ_DC', 'SEQOQ', 'SEQQ', 'SEQQ_DC', 'TDSTQ', 'TDSTQ_DC', 'TEQQ', 'TEQQ_DC', 'TFVAQ', 'TFVAQ_DC', 'TFVLQ', 'TFVLQ_DC', 'TSTKNQ', 'TSTKNQ_DC', 'TSTKQ', 'TSTKQ_DC', 'TXDBAQ', 'TXDBAQ_DC', 'TXDBCAQ', 'TXDBCLQ', 'TXDBQ', 'TXDBQ_DC', 'TXDITCQ', 'TXDITCQ_DC', 'TXDITQ', 'TXPQ', 'TXPQ_DC', 'TXPQ_FN', 'UACOQ', 'UACOQ_DC', 'UAOQ', 'UAOQ_DC', 'UAPTQ', 'UAPTQ_DC', 'UAPTQ_FN', 'UCAPSQ', 'UCAPSQ_DC', 'UCCONSQ', 'UCEQQ', 'UCONSWIPQ', 'UCONSWIPQ_DC', 'UDCLOQ', 'UDCLOQ_DC', 'UDCOPRESQ', 'UDCOPRESTQ', 'UDCOPRESTQ_DC', 'UDD1Q', 'UDD1Q_DC', 'UDD1Q_FN', 'UDDQ', 'UDDQ_DC', 'UDMBQ', 'UDMBQ_DC', 'UDOLTQ', 'UDOLTQ_DC', 'UDPCOQ', 'UDPCOQ_DC', 'UDUDDQ', 'UDUDDQ_DC', 'UDVPQ', 'UDVPQ_DC', 'UINVQ', 'UINVQ_DC', 'UITCBQ', 'UITCBQ_DC', 'UIVATQ', 'UIVATQ_DC', 'ULCOQ', 'UNORDC12', 'UNORDC12_DC', 'UNORDCQ', 'UNORDCQ_DC', 'UNPQ', 'UNPQ_DC', 'UNPQ_FN', 'UOPRDC12', 'UOPRDC12_DC', 'UOPRDCQ', 'UOPRDCQ_DC', 'UPMCSTKQ', 'UPMCSTKQ_DC', 'UPMPFQ', 'UPMPFQ_DC', 'UPMPFSQ', 'UPMPFSQ_DC', 'UPMSUBPQ', 'UPMSUBPQ_DC', 'UPSTKCQ', 'UPSTKCQ_DC', 'UPSTKQ', 'UPSTKQ_DC', 'UPTQ', 'UPTQ_FN', 'URECTQ', 'URECTQ_DC', 'USUBPCVQ', 'USUBPCVQ_DC', 'UTSTKCQ', 'UTSTKCQ_DC', 'UTSTKPQ', 'UTSTKPQ_DC', 'WCAPQ', 'XACCQ', 'XOPEXNBQ', 'XPPQ', 'XPPQ_DC']
# - documents-export-2025-3-19/incomestatementquarterly.parquet
#   columns (617): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'ACCHGQ', 'ACCHGQ_DC', 'ACCHGQ_FN', 'AQAQ', 'AQAQ_DC', 'AQAQ_FN', 'AQDQ', 'AQDQ_DC', 'AQDQ_FN', 'AQEPSQ', 'AQEPSQ_DC', 'AQEPSQ_FN', 'AQPQ', 'AQPQ_DC', 'AQPQ_FN', 'ARCEDQ', 'ARCEDQ_FN', 'ARCEEPSQ', 'ARCEEPSQ_FN', 'ARCEQ', 'ARCEQ_FN', 'CFPDOQ', 'CFPDOQ_DC', 'CIBEGNIQ', 'CIBEGNIQ_DC', 'CICURRQ', 'CICURRQ_DC', 'CIDERGLQ', 'CIDERGLQ_DC', 'CIMIIQ', 'CIMIIQ_DC', 'CIOTHERQ', 'CIOTHERQ_DC', 'CIPENQ', 'CIPENQ_DC', 'CIQ', 'CIQ_DC', 'CISECGLQ', 'CISECGLQ_DC', 'CITOTALQ', 'CITOTALQ_DC', 'CITOTALQ_FN', 'COGSQ', 'COGSQ_DC', 'COGSQ_FN1', 'CSH12Q', 'CSH12Q_DC', 'CSH12Q_FN', 'CSHFDQ', 'CSHFDQ_DC', 'CSHFDQ_FN', 'CSHPRQ', 'CSHPRQ_DC', 'CSHPRQ_FN', 'CSTKEQ', 'CSTKEQ_DC', 'DERHEDGLQ', 'DERHEDGLQ_DC', 'DERHEDGLQ_FN', 'DILAD12', 'DILADQ', 'DILADQ_DC', 'DILAV12', 'DILAVQ', 'DILAVQ_DC', 'DOQ', 'DOQ_DC', 'DPQ', 'DPQ_DC', 'DPQ_FN1', 'DPRETQ', 'DPRETQ_DC', 'DTEAQ', 'DTEAQ_DC', 'DTEAQ_FN', 'DTEDQ', 'DTEDQ_DC', 'DTEDQ_FN', 'DTEEPSQ', 'DTEEPSQ_DC', 'DTEEPSQ_FN', 'DTEPQ', 'DTEPQ_DC', 'DTEPQ_FN', 'DVPQ', 'DVPQ_DC', 'EPSF12', 'EPSF12_DC', 'EPSFIQ', 'EPSFIQ_DC', 'EPSFXQ', 'EPSFXQ_DC', 'EPSPIQ', 'EPSPIQ_DC', 'EPSPIQ_FN', 'EPSPXQ', 'EPSPXQ_DC', 'EPSPXQ_FN', 'EPSX12', 'EPSX12_DC', 'EPSX12_FN', 'ESUBQ', 'ESUBQ_DC', 'FCAQ', 'FCAQ_DC', 'FCAQ_FN1', 'FFOQ', 'FFOQ_DC', 'FINREVQ', 'FINREVQ_DC', 'FINXINTQ', 'FINXINTQ_DC', 'FINXOPRQ', 'FINXOPRQ_DC', 'GDWLAMQ', 'GDWLAMQ_DC', 'GDWLAMQ_FN1', 'GDWLIA12', 'GDWLIA12_FN', 'GDWLIAQ', 'GDWLIAQ_DC', 'GDWLIAQ_FN', 'GDWLID12', 'GDWLID12_FN', 'GDWLIDQ', 'GDWLIDQ_DC', 'GDWLIDQ_FN', 'GDWLIEPS12', 'GDWLIEPS12_FN', 'GDWLIEPSQ', 'GDWLIEPSQ_DC', 'GDWLIEPSQ_FN', 'GDWLIPQ', 'GDWLIPQ_DC', 'GDWLIPQ_FN', 'GLAQ', 'GLAQ_DC', 'GLAQ_FN', 'GLCEA12', 'GLCEA12_FN', 'GLCEAQ', 'GLCEAQ_DC', 'GLCEAQ_FN', 'GLCED12', 'GLCED12_FN', 'GLCEDQ', 'GLCEDQ_DC', 'GLCEDQ_FN', 'GLCEEPS12', 'GLCEEPS12_FN', 'GLCEEPSQ', 'GLCEEPSQ_DC', 'GLCEEPSQ_FN', 'GLCEPQ', 'GLCEPQ_DC', 'GLCEPQ_FN', 'GLDQ', 'GLDQ_DC', 'GLDQ_FN', 'GLEPSQ', 'GLEPSQ_DC', 'GLEPSQ_FN', 'GLIVQ', 'GLIVQ_DC', 'GLPQ', 'GLPQ_DC', 'GLPQ_FN', 'GMEXPQ', 'GMEXPQ_DC', 'GMFBEXPQ', 'GMFBEXPQ_DC', 'GMFBREVQ', 'GMFBREVQ_DC', 'GMOTHEXPQ', 'GMOTHREVQ', 'GMPROMQ', 'GMREVQ', 'GMREVQ_DC', 'GMRMEXPQ', 'GMRMEXPQ_DC', 'GMRMREVQ', 'GMRMREVQ_DC', 'GMTOTREVQ', 'HEDGEGLQ', 'HEDGEGLQ_DC', 'HEDGEGLQ_FN', 'IBADJ12', 'IBADJQ', 'IBADJQ_DC', 'IBADJQ_FN', 'IBCOMQ', 'IBCOMQ_DC', 'IBMIIQ', 'IBMIIQ_DC', 'IBQ', 'IBQ_DC', 'IBQ_FN1', 'IDITQ', 'IDITQ_DC', 'ISGTQ', 'ISGTQ_DC', 'MIIQ', 'MIIQ_DC', 'NIITQ', 'NIITQ_DC', 'NIMQ', 'NIMQ_DC', 'NIQ', 'NIQ_DC', 'NOPIQ', 'NOPIQ_DC', 'NOPIQ_FN1', 'NRTXTDQ', 'NRTXTDQ_DC', 'NRTXTDQ_FN', 'NRTXTEPSQ', 'NRTXTEPSQ_DC', 'NRTXTEPSQ_FN', 'NRTXTQ', 'NRTXTQ_DC', 'NRTXTQ_FN', 'OEPF12', 'OEPF12_FN', 'OEPS12', 'OEPS12_FN', 'OEPSXQ', 'OEPSXQ_DC', 'OEPSXQ_FN', 'OIADPQ', 'OIADPQ_DC', 'OIBDPQ', 'OIBDPQ_DC', 'OPEPSQ', 'OPEPSQ_DC', 'OPEPSQ_FN', 'ORFMQ', 'ORMMQ', 'ORMMQ_FN', 'ORMSALEQ', 'ORMSALEQ_DC', 'ORMSALEQ_FN', 'ORPSDQ', 'ORPSGQ', 'ORPSOQ', 'ORPSPQ', 'ORPSPQ_DC', 'ORPSTQ', 'ORPSTQ_FN', 'ORPYDQ', 'ORPYGQ', 'ORPYGQ_DC', 'ORPYOQ', 'ORPYPQ', 'ORPYPQ_DC', 'ORPYTQ', 'ORPYTQ_FN', 'PCLQ', 'PCLQ_DC', 'PIQ', 'PIQ_DC', 'PLLQ', 'PLLQ_DC', 'RCAQ', 'RCAQ_DC', 'RCAQ_FN', 'RCDQ', 'RCDQ_DC', 'RCDQ_FN', 'RCEPSQ', 'RCEPSQ_DC', 'RCEPSQ_FN', 'RCPQ', 'RCPQ_DC', 'RCPQ_FN', 'RDIPAQ', 'RDIPAQ_DC', 'RDIPAQ_FN', 'RDIPDQ', 'RDIPDQ_DC', 'RDIPDQ_FN', 'RDIPEPSQ', 'RDIPEPSQ_DC', 'RDIPEPSQ_FN', 'RDIPQ', 'RDIPQ_DC', 'RDIPQ_FN', 'REVTQ', 'REVTQ_DC', 'REVTQ_FN1', 'RRA12', 'RRA12_FN', 'RRAQ', 'RRAQ_DC', 'RRAQ_FN', 'RRD12', 'RRD12_FN', 'RRDQ', 'RRDQ_DC', 'RRDQ_FN', 'RREPS12', 'RREPS12_FN', 'RREPSQ', 'RREPSQ_DC', 'RREPSQ_FN', 'RRPQ', 'RRPQ_DC', 'RRPQ_FN', 'SALEQ', 'SALEQ_DC', 'SALEQ_FN1', 'SETA12', 'SETA12_FN', 'SETAQ', 'SETAQ_DC', 'SETAQ_FN', 'SETD12', 'SETD12_FN', 'SETDQ', 'SETDQ_DC', 'SETDQ_FN', 'SETEPS12', 'SETEPS12_FN', 'SETEPSQ', 'SETEPSQ_DC', 'SETEPSQ_FN', 'SETPQ', 'SETPQ_DC', 'SETPQ_FN', 'SPCE12', 'SPCE12_FN', 'SPCED12', 'SPCED12_FN', 'SPCEDPQ', 'SPCEDPQ_DC', 'S ...
# - documents-export-2025-3-19/incomestatementyeartodate.parquet
#   columns (474): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'ACCHGY', 'ACCHGY_DC', 'ACCHGY_FN', 'AQAY', 'AQAY_DC', 'AQAY_FN', 'AQDY', 'AQDY_DC', 'AQDY_FN', 'AQEPSY', 'AQEPSY_DC', 'AQEPSY_FN', 'AQPY', 'AQPY_DC', 'AQPY_FN', 'ARCEDY', 'ARCEDY_FN', 'ARCEEPSY', 'ARCEEPSY_FN', 'ARCEY', 'ARCEY_FN', 'CFPDOY', 'CFPDOY_DC', 'CIBEGNIY', 'CIBEGNIY_DC', 'CICURRY', 'CICURRY_DC', 'CIDERGLY', 'CIDERGLY_DC', 'CIMIIY', 'CIMIIY_DC', 'CIOTHERY', 'CIOTHERY_DC', 'CIPENY', 'CIPENY_DC', 'CISECGLY', 'CISECGLY_DC', 'CITOTALY', 'CITOTALY_DC', 'CITOTALY_FN', 'CIY', 'CIY_DC', 'COGSY', 'COGSY_DC', 'COGSY_FN1', 'CSHFDY', 'CSHFDY_DC', 'CSHFDY_FN', 'CSHPRY', 'CSHPRY_DC', 'CSHPRY_FN', 'CSTKEY', 'CSTKEY_DC', 'DERHEDGLY', 'DERHEDGLY_DC', 'DERHEDGLY_FN', 'DILADY', 'DILADY_DC', 'DILAVY', 'DILAVY_DC', 'DOY', 'DOY_DC', 'DPRETY', 'DPRETY_DC', 'DPY', 'DPY_DC', 'DPY_FN1', 'DTEAY', 'DTEAY_DC', 'DTEAY_FN', 'DTEDY', 'DTEDY_DC', 'DTEDY_FN', 'DTEEPSY', 'DTEEPSY_DC', 'DTEEPSY_FN', 'DTEPY', 'DTEPY_DC', 'DTEPY_FN', 'DVPY', 'DVPY_DC', 'EPSFIY', 'EPSFIY_DC', 'EPSFXY', 'EPSFXY_DC', 'EPSPIY', 'EPSPIY_DC', 'EPSPIY_FN', 'EPSPXY', 'EPSPXY_DC', 'EPSPXY_FN', 'ESUBY', 'ESUBY_DC', 'FCAY', 'FCAY_DC', 'FCAY_FN1', 'FFOY', 'FFOY_DC', 'FINREVY', 'FINREVY_DC', 'FINXINTY', 'FINXINTY_DC', 'FINXOPRY', 'FINXOPRY_DC', 'GDWLAMY', 'GDWLAMY_DC', 'GDWLAMY_FN1', 'GDWLIAY', 'GDWLIAY_DC', 'GDWLIAY_FN', 'GDWLIDY', 'GDWLIDY_DC', 'GDWLIDY_FN', 'GDWLIEPSY', 'GDWLIEPSY_DC', 'GDWLIEPSY_FN', 'GDWLIPY', 'GDWLIPY_DC', 'GDWLIPY_FN', 'GLAY', 'GLAY_DC', 'GLAY_FN', 'GLCEAY', 'GLCEAY_DC', 'GLCEAY_FN', 'GLCEDY', 'GLCEDY_DC', 'GLCEDY_FN', 'GLCEEPSY', 'GLCEEPSY_DC', 'GLCEEPSY_FN', 'GLCEPY', 'GLCEPY_DC', 'GLCEPY_FN', 'GLDY', 'GLDY_DC', 'GLDY_FN', 'GLEPSY', 'GLEPSY_DC', 'GLEPSY_FN', 'GLIVY', 'GLIVY_DC', 'GLPY', 'GLPY_DC', 'GLPY_FN', 'GMEXPY', 'GMEXPY_DC', 'GMFBEXPY', 'GMFBEXPY_DC', 'GMFBREVY', 'GMFBREVY_DC', 'GMOTHEXPY', 'GMOTHREVY', 'GMPROMY', 'GMREVY', 'GMREVY_DC', 'GMRMEXPY', 'GMRMEXPY_DC', 'GMRMREVY', 'GMRMREVY_DC', 'GMTOTREVY', 'HEDGEGLY', 'HEDGEGLY_DC', 'HEDGEGLY_FN', 'IBADJY', 'IBADJY_DC', 'IBADJY_FN', 'IBCOMY', 'IBCOMY_DC', 'IBMIIY', 'IBMIIY_DC', 'IBY', 'IBY_DC', 'IBY_FN1', 'IDITY', 'IDITY_DC', 'ISGTY', 'ISGTY_DC', 'MIIY', 'MIIY_DC', 'NCOY', 'NIITY', 'NIITY_DC', 'NIMY', 'NIMY_DC', 'NIY', 'NIY_DC', 'NOPIY', 'NOPIY_DC', 'NRTXTDY', 'NRTXTDY_DC', 'NRTXTDY_FN', 'NRTXTEPSY', 'NRTXTEPSY_DC', 'NRTXTEPSY_FN', 'NRTXTY', 'NRTXTY_DC', 'NRTXTY_FN', 'OEPSXY', 'OEPSXY_DC', 'OEPSXY_FN', 'OIADPY', 'OIADPY_DC', 'OIBDPY', 'OIBDPY_DC', 'OPEPSY', 'OPEPSY_DC', 'OPEPSY_FN', 'ORFMY', 'ORMMY', 'ORMMY_FN', 'ORMSALEY', 'ORMSALEY_DC', 'ORMSALEY_FN', 'ORPSDY', 'ORPSGY', 'ORPSOY', 'ORPSPY', 'ORPSPY_DC', 'ORPSTY', 'ORPSTY_FN', 'ORPYDY', 'ORPYGY', 'ORPYGY_DC', 'ORPYOY', 'ORPYPY', 'ORPYPY_DC', 'ORPYTY', 'ORPYTY_FN', 'PCLY', 'PCLY_DC', 'PIY', 'PIY_DC', 'PLLY', 'PLLY_DC', 'RCAY', 'RCAY_DC', 'RCAY_FN', 'RCDY', 'RCDY_DC', 'RCDY_FN', 'RCEPSY', 'RCEPSY_DC', 'RCEPSY_FN', 'RCPY', 'RCPY_DC', 'RCPY_FN', 'RDIPAY', 'RDIPAY_DC', 'RDIPAY_FN', 'RDIPDY', 'RDIPDY_DC', 'RDIPDY_FN', 'RDIPEPSY', 'RDIPEPSY_DC', 'RDIPEPSY_FN', 'RDIPY', 'RDIPY_DC', 'RDIPY_FN', 'REVTY', 'REVTY_DC', 'REVTY_FN1', 'RRAY', 'RRAY_DC', 'RRAY_FN', 'RRDY', 'RRDY_DC', 'RRDY_FN', 'RREPSY', 'RREPSY_DC', 'RREPSY_FN', 'RRPY', 'RRPY_DC', 'RRPY_FN', 'SALEY', 'SALEY_DC', 'SALEY_FN1', 'SETAY', 'SETAY_DC', 'SETAY_FN', 'SETDY', 'SETDY_DC', 'SETDY_FN', 'SETEPSY', 'SETEPSY_DC', 'SETEPSY_FN', 'SETPY', 'SETPY_DC', 'SETPY_FN', 'SPCEDPY', 'SPCEDPY_DC', 'SPCEDPY_FN', 'SPCEDY', 'SPCEDY_DC', 'SPCEDY_FN', 'SPCEEPSPY', 'SPCEEPSPY_DC', 'SPCEEPSPY_FN', 'SPCEEPSY', 'SPCEEPSY_DC', 'SPCEEPSY_FN', 'SPCEPY', 'SPCEPY_DC', 'SPCEPY_FN', 'SPCEY', 'SPCEY_DC', 'SPCEY_FN', 'SPIDY', 'SPIDY_DC', 'SPIDY_FN', 'SPIEPSY', 'SPIEPSY_DC', 'SPIEPSY_FN', 'SPIOAY', 'SPIOAY_DC', 'SPIOAY_FN', 'SPIOPY', 'SPIOPY_DC', 'SPIOPY_FN', 'SPIY', 'SPIY_DC', 'SRETY', 'SRETY_DC', 'STKCOY', 'STKCOY_DC', 'STKCOY_FN', 'STKCPAY', 'STKCPAY_DC', 'STKCPAY_FN', 'TDSGY', 'TDSGY_DC', 'TFVCEY', 'TFVCEY_DC', 'TFVCEY_FN', 'TIEY', 'TI ...
# - documents-export-2025-3-19/balancesheetindustrialannual.parquet
#   columns (735): ['KYGVKEY', 'KEYSET', 'FYYYY', 'fyra', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'ACDO', 'ACDO_DC', 'ACO', 'ACO_DC', 'ACODO', 'ACOFS', 'ACOFS_DC', 'ACOFS_FN', 'ACOMINC', 'ACOMINC_DC', 'ACOX', 'ACOX_DC', 'ACOXFS', 'ACOXFS_DC', 'ACOXFS_FN', 'ACQAO', 'ACQCSHI', 'ACQGDWL', 'ACQIC', 'ACQINTAN', 'ACQINVT', 'ACQLNTAL', 'ACQPPE', 'ACQSC', 'ACT', 'ALDO', 'ALDO_DC', 'ANO', 'AO', 'AOCIDERGL', 'AOCIDERGL_DC', 'AOCIDERGL_FN', 'AOCIOTHER', 'AOCIPEN', 'AOCIPEN_DC', 'AOCIPEN_FN', 'AOCISECGL', 'AOCISECGL_DC', 'AOCISECGL_FN', 'AODO', 'AOL2', 'AOX', 'AOX_DC', 'AP', 'AP_DC', 'AP_FN', 'APDPFS', 'APDPFS_DC', 'APDPFS_FN', 'APFS', 'APFS_DC', 'APFS_FN', 'APU', 'APU_DC', 'AQPL1', 'AT', 'AT_FN', 'AUL3', 'BAST', 'BAST_DC', 'BASTR', 'BASTR_DC', 'BILLEXCE', 'BILLEXCE_DC', 'BILLEXCE_FN', 'BKVLPS', 'BKVLPS_DC', 'CAPS', 'CAPS_DC', 'CAPS_FN', 'CAPSFT', 'CAPSFT_DC', 'CAPSFT_FN', 'CB', 'CB_DC', 'CEIEXBILL', 'CEIEXBILL_DC', 'CEIEXBILL_FN', 'CEQ', 'CEQ_DC', 'CEQL', 'CEQL_DC', 'CEQT', 'CEQT_DC', 'CH', 'CH_DC', 'CHE', 'CHE_DC', 'CHEFS', 'CHEFS_DC', 'CHEFS_FN', 'CHFS', 'CHFS_DC', 'CHFS_FN', 'CLD2', 'CLD2_DC', 'CLD3', 'CLD3_DC', 'CLD4', 'CLD4_DC', 'CLD5', 'CLD5_DC', 'CLG', 'CLG_DC', 'CLG_FN', 'CMP', 'CMP_DC', 'CSHI', 'CSHI_DC', 'CSHO', 'CSHO_DC', 'CSHO_FN', 'CSHR', 'CSHR_DC', 'CSHRC', 'CSHRC_DC', 'CSHRP', 'CSHRSO', 'CSHRT', 'CSHRT_DC', 'CSHRW', 'CSHRW_DC', 'CSTK', 'CSTK_DC', 'CSTK_FN', 'CSTKCV', 'CSTKCV_DC', 'DC', 'DC_DC', 'DCLO', 'DCLO_DC', 'DCLO_FN', 'DCOM', 'DCOM_DC', 'DCPSTK', 'DCPSTK_DC', 'DCS', 'DCS_DC', 'DCS_FN', 'DCVSR', 'DCVSR_DC', 'DCVSR_FN', 'DCVSUB', 'DCVSUB_DC', 'DCVSUB_FN', 'DCVT', 'DCVT_DC', 'DCVT_FN', 'DD', 'DD_DC', 'DD_FN', 'DD1', 'DD1_DC', 'DD1_FN', 'DD1FS', 'DD1FS_DC', 'DD1FS_FN', 'DD2', 'DD2_DC', 'DD2_FN', 'DD3', 'DD3_DC', 'DD3_FN', 'DD4', 'DD4_DC', 'DD4_FN', 'DD5', 'DD5_DC', 'DD5_FN', 'DERAC', 'DERAC_DC', 'DERAC_FN', 'DERALT', 'DERALT_DC', 'DERALT_FN', 'DERLC', 'DERLC_DC', 'DERLC_FN', 'DERLLT', 'DERLLT_DC', 'DERLLT_FN', 'DFS', 'DFS_DC', 'DFS_FN', 'DLC', 'DLC_DC', 'DLCFS', 'DLCFS_DC', 'DLCFS_FN', 'DLTO', 'DLTO_DC', 'DLTO_FN', 'DLTP', 'DLTP_DC', 'DLTP_FN', 'DLTT', 'DLTT_DC', 'DLTT_FN', 'DM', 'DM_DC', 'DN', 'DN_DC', 'DN_FN', 'DPACB', 'DPACB_DC', 'DPACC', 'DPACC_DC', 'DPACLI', 'DPACLS', 'DPACLS_DC', 'DPACME', 'DPACME_DC', 'DPACNR', 'DPACNR_DC', 'DPACO', 'DPACRE', 'DPACT', 'DPACT_DC', 'DPACT_FN', 'DPVIEB', 'DPVIEB_DC', 'DPVIO', 'DPVIO_DC', 'DPVIR', 'DPVIR_DC', 'DRC', 'DRC_DC', 'DRLT', 'DRLT_DC', 'DS', 'DS_DC', 'DS_FN', 'DT', 'DT_DC', 'DT_FN', 'DUDD', 'DUDD_DC', 'DVPA', 'DVPA_DC', 'DVPIBB', 'DVPIBB_DC', 'DXD2', 'DXD2_DC', 'DXD3', 'DXD3_DC', 'DXD4', 'DXD4_DC', 'DXD5', 'DXD5_DC', 'EMP', 'EMP_DC', 'EMP_FN', 'ESOPCT', 'ESOPCT_DC', 'ESOPDLT', 'ESOPNR', 'ESOPR', 'ESOPT', 'ESOPT_FN', 'FATB', 'FATB_DC', 'FATC', 'FATC_DC', 'FATE', 'FATE_DC', 'FATL', 'FATL_DC', 'FATN', 'FATN_DC', 'FATO', 'FATO_DC', 'FATP', 'FINACO', 'FINACO_DC', 'FINACO_FN', 'FINAO', 'FINAO_DC', 'FINAO_FN', 'FINCH', 'FINCH_DC', 'FINCH_FN', 'FINDLC', 'FINDLC_DC', 'FINDLC_FN', 'FINDLT', 'FINDLT_DC', 'FINDLT_FN', 'FINIVST', 'FINIVST_DC', 'FINIVST_FN', 'FINLCO', 'FINLCO_DC', 'FINLCO_FN', 'FINLTO', 'FINLTO_DC', 'FINLTO_FN', 'FINNP', 'FINNP_DC', 'FINNP_FN', 'FINRECC', 'FINRECC_DC', 'FINRECC_FN', 'FINRECLT', 'FINRECLT_DC', 'FINRECLT_FN', 'GDWL', 'GDWL_DC', 'ICAPT', 'ICAPT_DC', 'ICAPT_FN', 'INTAN', 'INTAN_DC', 'INTANO', 'INTANO_DC', 'INVFG', 'INVFG_DC', 'INVO', 'INVRM', 'INVRM_DC', 'INVT', 'INVT_DC', 'INVTFS', 'INVTFS_DC', 'INVTFS_FN', 'INVWIP', 'INVWIP_DC', 'ITCB', 'ITCB_DC', 'IVAEQ', 'IVAEQ_DC', 'IVAO', 'IVAO_DC', 'IVST', 'IVST_DC', 'IVSTFS', 'IVSTFS_DC', 'IVSTFS_FN', 'LCO', 'LCO_DC', 'LCOFS', 'LCOFS_DC', 'LCOFS_FN', 'LCOX', 'LCOX_DC', 'LCOXDR', 'LCT', 'LCT_DC', 'LCTFS', 'LCTFS_DC', 'LCTFS_FN', 'LIFR', 'LIFR_DC', 'LIFRP', 'LIFRP_DC', 'LIFRP_FN', 'LNO', 'LO', 'LO_DC', 'LOL2', 'LOXDR', 'LQPL1', 'LSE', 'LSE_FN', 'LT', 'LT_DC', 'LUL3', 'MIB', 'MIB_DC', 'MIBN', 'MIBN_DC', 'MIBN_FN', 'MIBT', 'MIBT_DC', 'MIBT_FN', 'MRC1', 'MRC1_DC', 'MRC1_FN', 'MRC2', 'MRC2_DC', 'MRC2_FN', 'MRC3', 'MRC3_DC', ' ...
# - documents-export-2025-3-19/securitytimeseriesdata.parquet
#   columns (28): ['KYGVKEY', 'KYIID', 'DATADATE', 'LPERMNO', 'LPERMCO', 'LinkRangeTypeCd', 'AJEXM', 'AJPM', 'CHEQVM', 'CSFSM', 'CSHTRM', 'CURCDDVM', 'CURCDM', 'SEC_CURCDQ', 'DVPSPM', 'DVPSXM', 'DVRATE', 'ISALRT', 'NAVM', 'SEC_NISA', 'SEC_NISA_DC', 'PRCCM', 'PRCHM', 'PRCLM', 'PRIMISS', 'SPGIM', 'SPIIM', 'SPMIM']
# - documents-export-2025-3-19/incomestatementindustrialannual.parquet
#   columns (741): ['KYGVKEY', 'KEYSET', 'FYYYY', 'fyra', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'ACCHG', 'ACCHG_DC', 'ACCHG_FN', 'ACCRT', 'ACCRT_DC', 'AM', 'AM_DC', 'AQA', 'AQA_DC', 'AQA_FN', 'AQD', 'AQD_DC', 'AQD_FN', 'AQEPS', 'AQEPS_DC', 'AQEPS_FN', 'AQI', 'AQI_DC', 'AQP', 'AQP_DC', 'AQP_FN', 'AQS', 'AQS_DC', 'AQS_FN', 'ARCE', 'ARCE_FN', 'ARCED', 'ARCED_FN', 'ARCEEPS', 'ARCEEPS_FN', 'CBI', 'CBI_DC', 'CI', 'CI_DC', 'CI_FN', 'CIBEGNI', 'CICURR', 'CICURR_DC', 'CIDERGL', 'CIDERGL_DC', 'CIMII', 'CIMII_DC', 'CIMII_FN', 'CIOTHER', 'CIPEN', 'CIPEN_DC', 'CISECGL', 'CISECGL_DC', 'CITOTAL', 'COGS', 'COGS_FN', 'CSHFD', 'CSHFD_DC', 'CSHFD_FN', 'CSHPRI', 'CSHPRI_DC', 'CSHPRI_FN', 'CSTKE', 'DBI', 'DBI_DC', 'DERHEDGL', 'DERHEDGL_DC', 'DFXA', 'DFXA_DC', 'DILADJ', 'DILAVX', 'DO', 'DO_DC', 'DONR', 'DONR_DC', 'DP', 'DP_DC', 'DP_FN', 'DPRET', 'DTEA', 'DTEA_DC', 'DTEA_FN', 'DTED', 'DTED_DC', 'DTED_FN', 'DTEEPS', 'DTEEPS_FN', 'DTEP', 'DTEP_DC', 'DTEP_FN', 'DVC', 'DVC_DC', 'DVP', 'DVP_DC', 'DVT', 'EBIT', 'EBITDA', 'EBITDA_DC', 'EPSFI', 'EPSFI_DC', 'EPSFX', 'EPSFX_DC', 'EPSPI', 'EPSPI_DC', 'EPSPI_FN', 'EPSPX', 'EPSPX_DC', 'EPSPX_FN', 'ESUB', 'ESUB_DC', 'ESUB_FN', 'FCA', 'FCA_DC', 'FCA_FN', 'FFO', 'FINREV', 'FINREV_DC', 'FINXINT', 'FINXINT_DC', 'FINXOPR', 'FINXOPR_DC', 'GDWLAM', 'GDWLAM_FN', 'GDWLIA', 'GDWLIA_DC', 'GDWLIA_FN', 'GDWLID', 'GDWLID_DC', 'GDWLID_FN', 'GDWLIEPS', 'GDWLIEPS_DC', 'GDWLIEPS_FN', 'GDWLIP', 'GDWLIP_DC', 'GDWLIP_FN', 'GLA', 'GLA_DC', 'GLA_FN', 'GLCEA', 'GLCEA_DC', 'GLCEA_FN', 'GLCED', 'GLCED_FN', 'GLCEEPS', 'GLCEEPS_FN', 'GLCEP', 'GLCEP_DC', 'GLCEP_FN', 'GLD', 'GLD_DC', 'GLD_FN', 'GLEPS', 'GLEPS_DC', 'GLEPS_FN', 'GLIV', 'GLIV_DC', 'GLP', 'GLP_DC', 'GLP_FN', 'GMEXP', 'GMEXP_DC', 'GMFBEXP', 'GMFBEXP_DC', 'GMFBPC', 'GMFBPC_DC', 'GMFBREV', 'GMFBREV_DC', 'GMOTHEXP', 'GMOTHPC', 'GMOTHREV', 'GMPROM', 'GMPROM_FN', 'GMREV', 'GMREV_DC', 'GMRMEXP', 'GMRMEXP_DC', 'GMRMPC', 'GMRMPC_DC', 'GMRMREV', 'GMRMREV_DC', 'GMTOTPC', 'GMTOTREV', 'GP', 'HEDGEGL', 'HEDGEGL_DC', 'HEDGEGL_FN', 'IB', 'IB_DC', 'IB_FN', 'IBADJ', 'IBADJ_DC', 'IBADJ_FN', 'IBCOM', 'IBCOM_DC', 'IBMII', 'IBMII_DC', 'IBMII_FN', 'IDIT', 'IDIT_DC', 'INTC', 'INTC_DC', 'IPTI', 'IPTI_DC', 'IRENT', 'IRENT_DC', 'ITCI', 'ITCI_DC', 'ITCI_FN', 'IVI', 'MII', 'MII_DC', 'NCO', 'NCO_DC', 'NI', 'NI_DC', 'NI_FN', 'NIADJ', 'NIECI', 'NIECI_DC', 'NIIT', 'NIM', 'NIPFC', 'NIPFP', 'NOPI', 'NOPI_DC', 'NOPIO', 'NOPIO_DC', 'NRTXT', 'NRTXT_DC', 'NRTXT_FN', 'NRTXTD', 'NRTXTD_DC', 'NRTXTD_FN', 'NRTXTEPS', 'NRTXTEPS_DC', 'NRTXTEPS_FN', 'OIADP', 'OIADP_DC', 'OIBDP', 'OIBDP_DC', 'OPEPS', 'OPEPS_FN', 'OPREPSX', 'OPREPSX_FN', 'ORFM', 'ORMM', 'ORMM_FN', 'ORMSALE', 'ORPSD', 'ORPSG', 'ORPSO', 'ORPSP', 'ORPSP_DC', 'ORPST', 'ORPST_FN', 'ORPYD', 'ORPYG', 'ORPYG_DC', 'ORPYO', 'ORPYP', 'ORPYP_DC', 'ORPYT', 'ORPYT_FN', 'PI', 'PI_DC', 'PIDOM', 'PIDOM_DC', 'PIDOM_FN', 'PIFO', 'PIFO_DC', 'PIFO_FN', 'PLL', 'PLL_DC', 'RCA', 'RCA_DC', 'RCA_FN', 'RCD', 'RCD_DC', 'RCD_FN', 'RCEPS', 'RCEPS_DC', 'RCEPS_FN', 'RCP', 'RCP_DC', 'RCP_FN', 'RDIP', 'RDIP_DC', 'RDIP_FN', 'RDIPA', 'RDIPA_DC', 'RDIPA_FN', 'RDIPD', 'RDIPD_FN', 'RDIPEPS', 'RDIPEPS_FN', 'REVT', 'REVT_FN', 'RRA', 'RRA_FN', 'RRD', 'RRD_FN', 'RREPS', 'RREPS_FN', 'RRP', 'RRP_FN', 'SALE', 'SALE_FN', 'SALEPFC', 'SALEPFP', 'SETA', 'SETA_DC', 'SETA_FN', 'SETD', 'SETD_DC', 'SETD_FN', 'SETEPS', 'SETEPS_DC', 'SETEPS_FN', 'SETP', 'SETP_DC', 'SETP_FN', 'SPCE', 'SPCE_FN', 'SPCED', 'SPCED_FN', 'SPCEEPS', 'SPCEEPS_FN', 'SPI', 'SPI_DC', 'SPID', 'SPID_DC', 'SPID_FN', 'SPIEPS', 'SPIEPS_DC', 'SPIEPS_FN', 'SPIOA', 'SPIOA_DC', 'SPIOA_FN', 'SPIOP', 'SPIOP_DC', 'SPIOP_FN', 'SRET', 'STKCO', 'STKCO_DC', 'STKCO_FN', 'STKCPA', 'STKCPA_DC', 'STKCPA_FN', 'TFVCE', 'TIE', 'TIE_FN', 'TII', 'TXC', 'TXDFED', 'TXDFED_DC', 'TXDFO', 'TXDFO_DC', 'TXDI', 'TXDI_DC', 'TXDS', 'TXDS_DC', 'TXFED', 'TXFED_DC', 'TXFED_FN', 'TXFO', 'TXFO_DC', 'TXFO_FN', 'TXO', 'TXO_FN', 'TXS', 'TXS_DC', 'TXS_FN', 'TXT', 'TXT_DC', 'TXT_FN', 'TXW', 'TXW_DC', 'UADA', 'UADA_DC', 'UADATE', 'UADX', 'UADX_DC', 'UAFUDC', 'UAFUDC_DC', 'UAFUDCB', 'UAFU ...
# - documents-export-2025-3-19/cashflowyeartodate.parquet
#   columns (126): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'AFUDCCY', 'AFUDCIY', 'AMCY', 'AMCY_DC', 'AOLOCHY', 'AOLOCHY_DC', 'APALCHY', 'APALCHY_DC', 'AQCY', 'AQCY_DC', 'CAPXY', 'CAPXY_DC', 'CAPXY_FN1', 'CDVCY', 'CDVCY_DC', 'CHECHY', 'CHECHY_DC', 'DEPCY', 'DEPCY_DC', 'DLCCHY', 'DLCCHY_DC', 'DLTISY', 'DLTISY_DC', 'DLTRY', 'DLTRY_DC', 'DPCY', 'DPCY_DC', 'DPCY_FN1', 'DVY', 'DVY_DC', 'ESUBCY', 'ESUBCY_DC', 'EXREY', 'EXREY_DC', 'FIAOY', 'FINCFY', 'FOPOXY', 'FOPOY', 'FOPTY', 'FSRCOY', 'FSRCTY', 'FUSEOY', 'FUSETY', 'IBCY', 'IBCY_DC', 'INTPNY', 'INTPNY_DC', 'INVCHY', 'INVCHY_DC', 'ITCCY', 'ITCCY_DC', 'IVACOY', 'IVCHY', 'IVCHY_DC', 'IVNCFY', 'IVSTCHY', 'IVSTCHY_DC', 'OANCFY', 'OANCFY_DC', 'OANCFY_FN1', 'PDVCY', 'PDVCY_DC', 'PRSTKCCY', 'PRSTKCCY_DC', 'PRSTKCY', 'PRSTKCY_DC', 'PRSTKPCY', 'PRSTKPCY_DC', 'RECCHY', 'RECCHY_DC', 'SCSTKCY', 'SCSTKCY_DC', 'SIVY', 'SIVY_DC', 'SPPEY', 'SPPEY_DC', 'SPPIVY', 'SPPIVY_DC', 'SPSTKCY', 'SPSTKCY_DC', 'SSTKY', 'SSTKY_DC', 'TDCY', 'TDCY_DC', 'TSAFCY', 'TXACHY', 'TXACHY_DC', 'TXBCOFY', 'TXBCOFY_DC', 'TXBCOY', 'TXBCOY_DC', 'TXDCY', 'TXDCY_DC', 'TXPDY', 'TXPDY_DC', 'UAOLOCHY', 'UAOLOCHY_DC', 'UDFCCY', 'UDFCCY_DC', 'UFRETSDY', 'UNWCCY', 'UNWCCY_DC', 'UOISY', 'UOISY_DC', 'UPTACY', 'UPTACY_DC', 'UPTACY_FN', 'USTDNCY', 'USTDNCY_DC', 'UTFDOCY', 'UTFOSCY', 'UUFOFY', 'UWKCAPCY', 'UWKCAPCY_DC', 'WCAPCHY', 'WCAPCY', 'WCAPCY_DC', 'XIDOCY', 'XIDOCY_DC']
# - documents-export-2025-3-19/semiannual.parquet
#   columns (325): ['KYGVKEY', 'KEYSET', 'FYYYYS', 'FYRS', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'ACCHGSA', 'ACCHGSA_DC', 'AQASA', 'AQASA_DC', 'AQDSA', 'AQDSA_DC', 'AQEPSSA', 'AQEPSSA_DC', 'AQPSA', 'AQPSA_DC', 'ARCEDSA', 'ARCEDSA_DC', 'ARCEEPSSA', 'ARCEEPSSA_DC', 'ARCESA', 'ARCESA_DC', 'CIBEGNISA', 'CIBEGNISA_DC', 'CICURRSA', 'CICURRSA_DC', 'CIDERGLSA', 'CIDERGLSA_DC', 'CIMIISA', 'CIMIISA_DC', 'CIOTHERSA', 'CIOTHERSA_DC', 'CIPENSA', 'CIPENSA_DC', 'CISA', 'CISA_DC', 'CISECGLSA', 'CISECGLSA_DC', 'CITOTALSA', 'CITOTALSA_DC', 'COGSSA', 'COGSSA_DC', 'COGSSA_FN1', 'CSHFDSA', 'CSHFDSA_DC', 'CSHFDSA_FN', 'CSHPRSA', 'CSHPRSA_DC', 'CSHPRSA_FN', 'CSTKESA', 'CSTKESA_DC', 'DERHEDGLSA', 'DERHEDGLSA_DC', 'DILADSA', 'DILADSA_DC', 'DILAVSA', 'DILAVSA_DC', 'DOSA', 'DOSA_DC', 'DPRETSA', 'DPRETSA_DC', 'DPSA', 'DPSA_DC', 'DPSA_FN1', 'DTEASA', 'DTEASA_DC', 'DTEDSA', 'DTEDSA_DC', 'DTEEPSSA', 'DTEEPSSA_DC', 'DTEPSA', 'DTEPSA_DC', 'DVPSA', 'DVPSA_DC', 'EPSFISA', 'EPSFISA_DC', 'EPSFXSA', 'EPSFXSA_DC', 'EPSPISA', 'EPSPISA_DC', 'EPSPISA_FN', 'EPSPXSA', 'EPSPXSA_DC', 'EPSPXSA_FN', 'ESUBSA', 'ESUBSA_DC', 'FCASA', 'FCASA_DC', 'FFOSA', 'FFOSA_DC', 'FINREVSA', 'FINREVSA_DC', 'FINXINTSA', 'FINXINTSA_DC', 'FINXOPRSA', 'FINXOPRSA_DC', 'GDWLAMSA', 'GDWLAMSA_DC', 'GDWLIASA', 'GDWLIASA_DC', 'GDWLIDSA', 'GDWLIDSA_DC', 'GDWLIEPSSA', 'GDWLIEPSSA_DC', 'GDWLIPSA', 'GDWLIPSA_DC', 'GLASA', 'GLASA_DC', 'GLCEASA', 'GLCEASA_DC', 'GLCEDSA', 'GLCEDSA_DC', 'GLCEEPSSA', 'GLCEEPSSA_DC', 'GLCEPSA', 'GLCEPSA_DC', 'GLDSA', 'GLDSA_DC', 'GLEPSSA', 'GLEPSSA_DC', 'GLIVSA', 'GLIVSA_DC', 'GLPSA', 'GLPSA_DC', 'HEDGEGLSA', 'HEDGEGLSA_DC', 'IBADJSA', 'IBADJSA_DC', 'IBCOMSA', 'IBCOMSA_DC', 'IBMIISA', 'IBMIISA_DC', 'IBSA', 'IBSA_DC', 'MIISA', 'MIISA_DC', 'MMIMPSA', 'NCOSA', 'NCOSA_DC', 'NIITSA', 'NIITSA_DC', 'NIMSA', 'NISA', 'NISA_DC', 'NOPISA', 'NOPISA_DC', 'NRTXTDSA', 'NRTXTDSA_DC', 'NRTXTEPSSA', 'NRTXTEPSSA_DC', 'NRTXTSA', 'NRTXTSA_DC', 'OEPSXSA', 'OEPSXSA_FN', 'OIADPSA', 'OIADPSA_DC', 'OIBDPSA', 'OIBDPSA_DC', 'OPEPSSA', 'OPEPSSA_DC', 'OPEPSSA_FN', 'OPTDRSA', 'OPTFVGRSA', 'OPTLIFESA', 'OPTRFRSA', 'OPTVOLSA', 'PISA', 'PISA_DC', 'PLLSA', 'PLLSA_DC', 'PNCDSA', 'PNCEPSSA', 'PNCIAPSA', 'PNCIASA', 'PNCIDPSA', 'PNCIDSA', 'PNCIEPSPSA', 'PNCIEPSSA', 'PNCIPPSA', 'PNCIPSA', 'PNCPDSA', 'PNCPEPSSA', 'PNCPSA', 'PNCSA', 'PNCWIAPSA', 'PNCWIASA', 'PNCWIDPSA', 'PNCWIDSA', 'PNCWIEPSA', 'PNCWIEPSSA', 'PNCWIPPSA', 'PNCWIPSA', 'PRCASA', 'PRCDSA', 'PRCEPSSA', 'PRCPDSA', 'PRCPEPSSA', 'PRCPSA', 'RCASA', 'RCASA_DC', 'RCDSA', 'RCDSA_DC', 'RCEPSSA', 'RCEPSSA_DC', 'RCPSA', 'RCPSA_DC', 'RDIPASA', 'RDIPASA_DC', 'RDIPDSA', 'RDIPDSA_DC', 'RDIPEPSSA', 'RDIPSA', 'RDIPSA_DC', 'REVTSA', 'REVTSA_DC', 'REVTSA_FN1', 'RRASA', 'RRASA_DC', 'RRDSA', 'RRDSA_DC', 'RREPSSA', 'RREPSSA_DC', 'RRPSA', 'RRPSA_DC', 'SALESA', 'SALESA_DC', 'SALESA_FN1', 'SETASA', 'SETASA_DC', 'SETDSA', 'SETDSA_DC', 'SETEPSSA', 'SETEPSSA_DC', 'SETPSA', 'SETPSA_DC', 'SPCEDPSA', 'SPCEDSA', 'SPCEEPSPSA', 'SPCEEPSSA', 'SPCEPSA', 'SPCEPSA_DC', 'SPCESA', 'SPCESA_DC', 'SPIDSA', 'SPIDSA_DC', 'SPIEPSSA', 'SPIEPSSA_DC', 'SPIOASA', 'SPIOASA_DC', 'SPIOPSA', 'SPIOPSA_DC', 'SPISA', 'SPISA_DC', 'SRETSA', 'SRETSA_DC', 'STKCOSA', 'STKCOSA_DC', 'STKCPASA', 'STKCPASA_DC', 'TFVCESA', 'TFVCESA_DC', 'TIESA', 'TIESA_DC', 'TIESA_FN', 'TIISA', 'TIISA_DC', 'TXDISA', 'TXDISA_DC', 'TXTSA', 'TXTSA_DC', 'TXWSA', 'TXWSA_DC', 'UDVPSA', 'UDVPSA_DC', 'UGISA', 'UGISA_DC', 'UNIAMISA', 'UNIAMISA_DC', 'UNOPINCSA', 'UNOPINCSA_DC', 'UOPISA', 'UOPISA_DC', 'UPDVPSA', 'UPDVPSA_DC', 'USPISA', 'USPISA_DC', 'USUBDVPSA', 'USUBDVPSA_DC', 'UTEMSA', 'UTEMSA_DC', 'WDASA', 'WDASA_DC', 'WDDSA', 'WDDSA_DC', 'WDEPSSA', 'WDEPSSA_DC', 'WDPSA', 'WDPSA_DC', 'XIDOSA', 'XIDOSA_DC', 'XINTSA', 'XINTSA_DC', 'XINTSA_FN1', 'XISA', 'XISA_DC', 'XOPRSA', 'XOPRSA_DC', 'XOPTDQPSA', 'XOPTDQPSA_DC', 'XOPTDSA', 'XOPTDSA_DC', 'XOPTEPSQPSA', 'XOPTEPSQPSA_DC', 'XOPTEPSSA', 'XOPTEPSSA_DC', 'XOPTQPSA', 'XOPTQPSA_DC', 'XOPTSA', 'XOPTSA_DC', 'XRDSA', 'XRDSA_DC', 'XRDSA_FN', 'XSGASA', 'XSGASA_DC']
# - documents-export-2025-3-19/operatingsegmentitem.parquet
#   columns (34): ['KYGVKEY', 'SI_SRCYR', 'SI_SRCFYR', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'SI_STYPE', 'SI_SID', 'SI_DATYR', 'SI_FISCYR', 'SI_CALYR', 'SI_EMP', 'SI_SALE', 'SI_OIBD', 'SI_DP', 'SI_OIAD', 'SI_CAPX', 'SI_IAT', 'SI_EQEARN', 'SI_INVEQ', 'SI_RD', 'SI_OBKLG', 'SI_EXPORTS', 'SI_INTSEG', 'SI_OPINC', 'SI_PI', 'SI_IB', 'SI_NI', 'SI_SALEF', 'SI_OPINCF', 'SI_CAPXF', 'SI_EQEARNF', 'SI_EMPF', 'SI_RDF']
# - documents-export-2025-3-19/calendarmarketdataquarterly.parquet
#   columns (14): ['KYGVKEY', 'DATADATE', 'LPERMNO', 'LPERMCO', 'LinkRangeTypeCd', 'KEYSET', 'CLSMQ', 'CSHTRQ', 'DVPSPQ', 'DVPSXQ', 'MKVALTQ', 'PRCCQ', 'PRCHQ', 'PRCLQ']
# - documents-export-2025-3-19/cashflowannual.parquet
#   columns (139): ['KYGVKEY', 'KEYSET', 'FYYYY', 'fyra', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'AFUDCC', 'AFUDCC_FN', 'AFUDCI', 'AMC', 'AMC_DC', 'AMC_FN', 'AOLOCH', 'AOLOCH_DC', 'APALCH', 'APALCH_DC', 'AQC', 'AQC_DC', 'CAPX', 'CAPX_DC', 'CAPX_FN', 'CAPXV', 'CAPXV_DC', 'CDVC', 'CDVC_DC', 'CDVC_FN', 'CHECH', 'CHECH_DC', 'DEPC', 'DEPC_DC', 'DEPC_FN', 'DLCCH', 'DLCCH_DC', 'DLTIS', 'DLTIS_DC', 'DLTR', 'DLTR_DC', 'DPC', 'DPC_DC', 'DPC_FN', 'DV', 'DV_DC', 'DVINTF', 'DVINTF_DC', 'DVINTF_FN', 'ESUBC', 'ESUBC_DC', 'EXRE', 'EXRE_DC', 'FIAO', 'FINCF', 'FOPO', 'FOPO_DC', 'FOPOX', 'FOPT', 'FSRCO', 'FSRCO_DC', 'FSRCT', 'FUSEO', 'FUSEO_DC', 'FUSET', 'IBC', 'INTPN', 'INTPN_DC', 'INVCH', 'INVCH_DC', 'ITCC', 'ITCC_DC', 'ITCC_FN', 'IVACO', 'IVCH', 'IVCH_DC', 'IVNCF', 'IVSTCH', 'IVSTCH_DC', 'OANCF', 'OANCF_FN', 'PDVC', 'PDVC_DC', 'PDVC_FN', 'PRSTKC', 'PRSTKC_DC', 'PRSTKCC', 'PRSTKCC_DC', 'PRSTKPC', 'PRSTKPC_DC', 'RECCH', 'RECCH_DC', 'SCSTKC', 'SCSTKC_DC', 'SIV', 'SIV_DC', 'SPPE', 'SPPE_DC', 'SPPIV', 'SPPIV_DC', 'SPSTKC', 'SPSTKC_DC', 'SSTK', 'SSTK_DC', 'TDC', 'TDC_DC', 'TDC_FN', 'TSAFC', 'TXACH', 'TXACH_DC', 'TXBCO', 'TXBCO_DC', 'TXBCOF', 'TXBCOF_DC', 'TXDC', 'TXDC_DC', 'TXPD', 'TXPD_DC', 'UAOLOCH', 'UAOLOCH_DC', 'UDFCC', 'UDFCC_DC', 'UFRETSD', 'UNWCC', 'UNWCC_DC', 'UNWCC_FN', 'UOIS', 'UPTAC', 'UPTAC_DC', 'UPTAC_FN', 'USTDNC', 'USTDNC_DC', 'UTFDOC', 'UTFOSC', 'UUFOF', 'UWKCAPC', 'UWKCAPC_DC', 'WCAPC', 'WCAPC_DC', 'WCAPCH', 'XIDOC', 'XIDOC_DC']
# - documents-export-2025-3-19/fiscalmarketdataquarterly.parquet
#   columns (14): ['KYGVKEY', 'DATADATE', 'LPERMNO', 'LPERMCO', 'LinkRangeTypeCd', 'KEYSET', 'CLSMQ', 'CSHTRQ', 'DVPSPQ', 'DVPSXQ', 'MKVALTQ', 'PRCCQ', 'PRCHQ', 'PRCLQ']
# - documents-export-2025-3-19/bankquarterly.parquet
#   columns (248): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'AAMQ', 'AHSQ', 'AHSQ_DC', 'AMGWQ', 'AMGWQ_DC', 'AOCOEQ', 'AOCOEQ_DC', 'AOCORQ', 'AOCORQ_DC', 'AOMQ', 'AROLQ', 'AROLQ_DC', 'BMIIQ', 'BMIIQ_DC', 'BRCLQ', 'BRCLQ_DC', 'CDBIQ', 'CDBIQ_DC', 'CDBNIQ', 'CDBTQ', 'CDBTQ_DC', 'CDBTQ_FN', 'CMPQ', 'CMPQ_DC', 'CNDQ', 'CNDQ_DC', 'COEITQ', 'COEITQ_DC', 'CSHFD12', 'CSTKCVQ', 'DATPQ', 'DATPQ_DC', 'DD1Q', 'DD1Q_DC', 'DIBQ', 'DLTCCQ', 'DLTCCQ_DC', 'DPDCQ', 'DPDCQ_DC', 'DPSCQ', 'DPSCQ_DC', 'DPTICQ', 'DPTICQ_FN', 'DVCQ', 'DVCQ_DC', 'EPSFI12', 'EPSPI12', 'FCCQ', 'FCCQ_DC', 'FDACQ', 'FDACQ_DC', 'FDFRQ', 'FDFRQ_DC', 'FEDRCSQ', 'FEDRCSQ_DC', 'FEOENQ', 'FEOENQ_DC', 'FFPSSQ', 'FFPSSQ_DC', 'FFSQ', 'FFSQ_DC', 'FFSSPQ', 'FFSSPQ_DC', 'FFSSPQ_FN', 'FHLBQ', 'FHLBQ_DC', 'FLSQ', 'FLSQ_DC', 'FOQ', 'FOQ_DC', 'GLOQ', 'GLOQ_DC', 'ICNDQ', 'ICNDQ_DC', 'IDBIQ', 'IDBIQ_DC', 'IDIISQ', 'IDIISQ_DC', 'IDILBCQ', 'IDILBCQ_DC', 'IDILBCQ_FN', 'IDISQ', 'IDISQ_DC', 'IDITSQ', 'IDITSQ_DC', 'IDOTSQ', 'IDOTSQ_DC', 'IDOTSQ_FN', 'IDTSQ', 'IDTSQ_DC', 'IFFSSPQ', 'IFFSSPQ_DC', 'IFFSSPQ_FN', 'ILTDNCQ', 'ILTDNCQ_DC', 'IOSPSQ', 'IOSPSQ_DC', 'IREOQ', 'IREOQ_DC', 'ISGACQ', 'ISGACQ_DC', 'ITACOEQ', 'ITACOEQ_DC', 'ITACOEQ_FN', 'LCALQ', 'LCALQ_DC', 'LGQ', 'LHSQ', 'LHSQ_DC', 'LNDLFQ', 'LNDLFQ_FN', 'LNTALQ', 'LNTALQ_DC', 'LNTALQ_FN', 'MBSHSQ', 'MBSHSQ_DC', 'MIAFPIRQ', 'MIAFPIRQ_DC', 'MTGIQ', 'MTGIQ_DC', 'NATPIRQ', 'NATPIRQ_DC', 'NATPIRQ_FN', 'NATPIRXQ', 'NATPIRXQ_DC', 'NCOEACQ', 'NCOEACQ_DC', 'NCOEMIQ', 'NCOEMIQ_DC', 'NCOEPSFXQ', 'NCOEPSFXQ_DC', 'NCOEPSPX12', 'NCOEPSPXQ', 'NCOEPSPXQ_DC', 'NCOEPSPXQ_FN', 'NCOEQ', 'NCOEQ_DC', 'NIADJQ', 'NIADJQ_DC', 'NIINTQ', 'NIINTQ_DC', 'NIIPLQ', 'NIIPLQ_DC', 'NPAOREQ', 'NPAOREQ_DC', 'NREQ', 'NREQ_DC', 'NRIQ', 'NRIQ_DC', 'OAHSQ', 'OAHSQ_DC', 'OBQ', 'OBQ_DC', 'OCOEQ', 'OCOEQ_DC', 'OCORQ', 'OCORQ_DC', 'OEBPNQ', 'OEBPNQ_DC', 'OLBMQ', 'OLBMQ_DC', 'ONIIQ', 'ONIIQ_DC', 'OSPSQ', 'OSPSQ_DC', 'OSTQ', 'OSTQ_DC', 'OSTQ_FN', 'PSHOQ', 'PSTKLQ', 'PSTKLQ_DC', 'PVOAQ', 'PVOAQ_DC', 'RAGRQ', 'RAGRQ_DC', 'RCLQ', 'RCLQ_DC', 'RCOCRQ', 'REAJOQ', 'REAJOQ_DC', 'RECINTQ', 'RECINTQ_DC', 'RPAGQ', 'RPAGQ_DC', 'SCDAQ', 'SCDAQ_DC', 'SCECCQ', 'SCECCQ_DC', 'SHSQ', 'SOUSGAQ', 'SOUSGAQ_DC', 'STBOQ', 'STBOQ_DC', 'TAIQ', 'TAIQ_DC', 'TBQ', 'TBQ_DC', 'TBQ_FN', 'TCOEQ', 'TCOEQ_DC', 'TCOEQ_FN', 'TCORQ', 'TCORQ_DC', 'TCORQ_FN', 'TDOMDQ', 'TEPLQ', 'TEPLQ_DC', 'TFDQ', 'TFQ', 'TFQ_DC', 'TNIIQ', 'TNIIQ_DC', 'TRBDIUPQ', 'TRBDIUPQ_DC', 'TSTKCQ', 'TSTKCQ_DC', 'TSTKPQ', 'TTISQ', 'TXIIQ', 'TXIIQ_DC', 'UIQ', 'UIQ_DC', 'UIQ_FN', 'USTSQ', 'USTSQ_DC', 'XADQ', 'XADQ_DC', 'XFFPSSQ', 'XFFPSSQ_DC', 'XINDCQ', 'XINDCQ_DC', 'XINSQ', 'XINSQ_DC', 'XNITBQ', 'XNITBQ_DC', 'XOREOQ', 'XOREOQ_DC', 'XPRBQ', 'XPRBQ_DC', 'XSTFWSQ', 'XSTFWSQ_DC']
# - documents-export-2025-3-19/companyhistory.parquet
#   columns (43): ['KYGVKEY', 'HCHGDT', 'HCHGENDDT', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'HCIK', 'HEIN', 'HSTKO', 'HCONM', 'HFYRC', 'HCOSTAT', 'HIPODATE', 'HDLDTE', 'HDLRSN', 'HPRIUSA', 'HPRICAN', 'HPRIROW', 'HIDBFLAG', 'HFIC', 'HLOC', 'HINCORP', 'HSTATE', 'HCOUNTY', 'HCITY', 'HSIC', 'HNAICS', 'HGSECTOR', 'HGGROUP', 'HGIND', 'HGSUBIND', 'HSPCINDCD', 'HSPCSECCD', 'HCONML', 'HWEBURL', 'HPHONE', 'HFAX', 'HADD1', 'HADD2', 'HADD3', 'HADD4', 'HADDZIP', 'HBUSDESC']
# - documents-export-2025-3-19/linkfiscalperiodall.parquet
#   columns (20): ['KYGVKEY', 'fiscalperiod', 'FiscalYearEndMonthNbr', 'FiscalPeriodTypeCd', 'linkrank', 'FiscalPeriodStartDt', 'FiscalPeriodEndDt', 'lpermno', 'lpermco', 'liid', 'LinkRangeTypeCd', 'linktype', 'linkprim', 'LinkMadeCnt', 'LinkPERMNOCnt', 'LinkNonZeroPERMNOCnt', 'FiscalPeriodCRSPStartDt', 'FiscalPeriodCRSPEndDt', 'linkdt', 'linkenddt']
# - documents-export-2025-3-19/fiscalmarketdataannual.parquet
#   columns (14): ['KYGVKEY', 'DATADATE', 'LPERMNO', 'LPERMCO', 'LinkRangeTypeCd', 'KEYSET', 'CLSM', 'CSHTR', 'DVPSP', 'DVPSX', 'MKVALT', 'PRCC', 'PRCH', 'PRCL']
# - documents-export-2025-3-19/calendarmarketdataannual.parquet
#   columns (14): ['KYGVKEY', 'DATADATE', 'LPERMNO', 'LPERMCO', 'LinkRangeTypeCd', 'KEYSET', 'CLSM', 'CSHTR', 'DVPSP', 'DVPSX', 'MKVALT', 'PRCC', 'PRCH', 'PRCL']
# - documents-export-2025-3-19/filingdates.parquet
#   columns (10): ['KYGVKEY', 'FDATADATE', 'LPERMNO', 'LPERMCO', 'LinkRangeTypeCd', 'FCONSOL', 'FPOPSRC', 'SRCTYPE', 'FILEDATE', 'FILEDATETIME']
# - documents-export-2025-3-19/perioddescriptorquarterly.parquet
#   columns (33): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'ACCTCHGQ', 'ADRRQ', 'AJEXQ', 'AJPQ', 'APDEDATEQ', 'BSPRQ', 'COMPSTQ', 'CURCDQ', 'CURNCDQ', 'CURRTRQ', 'CURUSCNQ', 'DATACQTR', 'DATAFQTR', 'FDATEQ', 'FINALQ', 'FQTR', 'FYEARQ', 'LTDDQ', 'OGMQ', 'PDATEQ', 'RDQ', 'RP', 'SCFQ', 'SRCQ', 'STALTQ', 'UPDQ']
# - documents-export-2025-3-19/indexquarterly.parquet
#   columns (55): ['KYGVKEYX', 'DATADATE', 'IDX_ACOQ', 'IDX_ACTQ', 'IDX_AOQ', 'IDX_APQ', 'IDX_ATQ', 'IDX_CAPSQ', 'IDX_CAPXQX', 'IDX_CEQQ', 'IDX_CHEQ', 'IDX_COGSQ', 'IDX_CSTKEQ', 'IDX_CSTKQ', 'IDX_DLCQ', 'IDX_DLTTQ', 'IDX_DPQ', 'IDX_DVPQ', 'IDX_EPSFXQ', 'IDX_EPSPXQ', 'IDX_EPSX12', 'IDX_IBADJQ', 'IDX_IBCOMQ', 'IDX_IBQ', 'IDX_ICAPTQ', 'IDX_INVTQ', 'IDX_LCOQ', 'IDX_LCTQ', 'IDX_LOQ', 'IDX_LTQ', 'IDX_MIBNQ', 'IDX_MIBQ', 'IDX_MIBTQ', 'IDX_MIIQ', 'IDX_NIQ', 'IDX_NOPIQ', 'IDX_OEPSXQ', 'IDX_OIADPQ', 'IDX_OIBDPQ', 'IDX_OPEPSQ', 'IDX_PIQ', 'IDX_PPENTQ', 'IDX_PSTKQ', 'IDX_RECTQ', 'IDX_REQ', 'IDX_SALEQ', 'IDX_SEQQ', 'IDX_SPIQ', 'IDX_TEQQ', 'IDX_TSTKQ', 'IDX_TXDITQ', 'IDX_TXPQ', 'IDX_TXTQ', 'IDX_XINTQ', 'IDX_XSGAQ']
# - documents-export-2025-3-19/pensionyeartodate.parquet
#   columns (80): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'PBECERY', 'PBECERY_DC', 'PBECERY_FN', 'PBECY', 'PBECY_DC', 'PBECY_FN', 'PNCDY', 'PNCDY_FN', 'PNCEPSY', 'PNCEPSY_FN', 'PNCIAPY', 'PNCIAPY_FN', 'PNCIAY', 'PNCIAY_FN', 'PNCIDPY', 'PNCIDPY_FN', 'PNCIDY', 'PNCIDY_FN', 'PNCIEPSPY', 'PNCIEPSPY_FN', 'PNCIEPSY', 'PNCIEPSY_FN', 'PNCIPPY', 'PNCIPY', 'PNCPDY', 'PNCPDY_FN', 'PNCPEPSY', 'PNCPEPSY_FN', 'PNCPY', 'PNCPY_FN', 'PNCWIAPY', 'PNCWIAPY_FN', 'PNCWIAY', 'PNCWIAY_FN', 'PNCWIDPY', 'PNCWIDPY_FN', 'PNCWIDY', 'PNCWIDY_FN', 'PNCWIEPSY', 'PNCWIEPSY_FN', 'PNCWIEPY', 'PNCWIEPY_FN', 'PNCWIPPY', 'PNCWIPY', 'PNCY', 'PNCY_FN', 'PPCY', 'PPCY_DC', 'PPCY_FN', 'PPICY', 'PPICY_DC', 'PPICY_FN', 'PPOPCCY', 'PPOPCCY_DC', 'PPOPCCY_FN', 'PPRPAY', 'PPRPAY_DC', 'PPRPAY_FN', 'PPSCY', 'PPSCY_DC', 'PPSCY_FN', 'PRCAY', 'PRCAY_FN', 'PRCDY', 'PRCDY_FN', 'PRCEPSY', 'PRCEPSY_FN', 'PRCPDY', 'PRCPDY_FN', 'PRCPEPSY', 'PRCPEPSY_FN', 'PRCPY', 'PRCPY_FN']
# - documents-export-2025-3-19/companyratings.parquet
#   columns (10): ['KYGVKEY', 'DATADATE', 'LPERMNO', 'LPERMCO', 'LinkRangeTypeCd', 'SPCSRM', 'SPLTICRM', 'SPSDRM', 'SPSTICRM', 'XPFBETA']
# - documents-export-2025-3-19/pensionannual.parquet
#   columns (185): ['KYGVKEY', 'KEYSET', 'FYYYY', 'fyra', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'PADDML', 'PADDML_DC', 'PBACO', 'PBACO_DC', 'PBACOMIN', 'PBACOMIN_DC', 'PBACU', 'PBACU_DC', 'PBALO', 'PBALT', 'PBALT_DC', 'PBARAT', 'PBARAT_DC', 'PBARR', 'PBARR_FN', 'PBARRMAX', 'PBARRMIN', 'PBBAT', 'PBBAT_DC', 'PBEC', 'PBEC_DC', 'PBECE', 'PBECE_FN', 'PBID', 'PBINTAN', 'PBINTAN_DC', 'PBLC', 'PBLC_DC', 'PBLLT', 'PBLLT_DC', 'PBNAA', 'PBNAA_DC', 'PBNVV', 'PBNVV_DC', 'PBOA', 'PBOA_DC', 'PBP', 'PBP_DC', 'PBPC', 'PBPC_DC', 'PBPRO', 'PBPRO_DC', 'PBPRU', 'PBPRU_DC', 'PBPVN', 'PBPVN_DC', 'PBVNO', 'PBVNO_DC', 'PBVNU', 'PBVNU_DC', 'PBXACC', 'PBXACC_DC', 'PBXAT', 'PBXAT_DC', 'PCPPAO', 'PCPPAO_DC', 'PCPPAO_FN', 'PCPPAU', 'PCPPAU_DC', 'PCPPAU_FN', 'PCUP', 'PCUP_DC', 'PCUPSO', 'PCUPSO_DC', 'PCUPSU', 'PCUPSU_DC', 'PCUV', 'PCUV_DC', 'PNATD', 'PNATD_DC', 'PNATE', 'PNATE_DC', 'PNATE_FN', 'PNATO', 'PNATR', 'PNATR_DC', 'PNCA', 'PNCA_FN', 'PNCAD', 'PNCAD_FN', 'PNCAEPS', 'PNCAEPS_FN', 'PNCIA', 'PNCIA_FN', 'PNCID', 'PNCID_FN', 'PNCIEPS', 'PNCIEPS_FN', 'PNCIP', 'PNCWIA', 'PNCWIA_FN', 'PNCWID', 'PNCWID_FN', 'PNCWIEPS', 'PNCWIEPS_FN', 'PNCWIP', 'POAJO', 'POAJO_DC', 'POAJU', 'POAJU_DC', 'PPC', 'PPC_DC', 'PPCR', 'PPCR_FN', 'PPCRMAX', 'PPCRMIN', 'PPIC', 'PPIC_DC', 'PPLAO', 'PPLAO_DC', 'PPLAU', 'PPLAU_DC', 'PPOPCC', 'PPOPCC_DC', 'PPRBC', 'PPRBC_DC', 'PPRCI', 'PPRCI_FN', 'PPRCIMAX', 'PPRCIMIN', 'PPROR', 'PPROR_FN', 'PPRORMAX', 'PPRORMIN', 'PPRPA', 'PPRPA_DC', 'PPSC', 'PPSC_DC', 'PRAA', 'PRAA_DC', 'PRAC', 'PRAC_DC', 'PRALT', 'PRALT_DC', 'PRAMUTO', 'PRAMUTO_DC', 'PRARAT', 'PRARAT_DC', 'PRBA', 'PRBA_DC', 'PRBAT', 'PRBAT_DC', 'PRBO', 'PRBO_DC', 'PRCA', 'PRCA_FN', 'PRCAD', 'PRCAD_FN', 'PRCAEPS', 'PRCAEPS_FN', 'PREC', 'PREC_DC', 'PRIC', 'PRIC_DC', 'PRLC', 'PRLC_DC', 'PRLLT', 'PRLLT_DC', 'PROAD', 'PROAD_DC', 'PROADJ', 'PROADJ_DC', 'PROAJ', 'PROAJ_DC', 'PRP', 'PRP_DC', 'PRPC', 'PRPC_DC', 'PRPSC', 'PRPSC_DC', 'PRRPE', 'PRRPE_DC', 'PRSC', 'PRSC_DC', 'PRUTO', 'PRUTO_DC', 'PVPL', 'PVPL_DC']
# - documents-export-2025-3-19/exchangeratemonthlyaverages.parquet
#   columns (21): ['KYCURRENCY', 'KEYSET_TAG', 'DATADATE', 'EXRAT1M', 'EXRAT2M', 'EXRAT3M', 'EXRAT4M', 'EXRAT5M', 'EXRAT6M', 'EXRAT7M', 'EXRAT8M', 'EXRAT9M', 'EXRAT10M', 'EXRAT11M', 'EXRAT12M', 'EXRAT13M', 'EXRAT14M', 'EXRAT15M', 'EXRAT16M', 'EXRAT17M', 'EXRAT18M']
# - documents-export-2025-3-19/pensionquarterly.parquet
#   columns (100): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'PBECERQ', 'PBECERQ_DC', 'PBECERQ_FN', 'PBECQ', 'PBECQ_DC', 'PBECQ_FN', 'PNC12', 'PNC12_FN', 'PNCD12', 'PNCD12_FN', 'PNCDQ', 'PNCDQ_FN', 'PNCEPS12', 'PNCEPS12_FN', 'PNCEPSQ', 'PNCEPSQ_FN', 'PNCIAPQ', 'PNCIAPQ_FN', 'PNCIAQ', 'PNCIAQ_FN', 'PNCIDPQ', 'PNCIDPQ_FN', 'PNCIDQ', 'PNCIDQ_FN', 'PNCIEPSPQ', 'PNCIEPSPQ_FN', 'PNCIEPSQ', 'PNCIEPSQ_FN', 'PNCIPPQ', 'PNCIPQ', 'PNCPD12', 'PNCPD12_FN', 'PNCPDQ', 'PNCPDQ_FN', 'PNCPEPS12', 'PNCPEPS12_FN', 'PNCPEPSQ', 'PNCPEPSQ_FN', 'PNCPQ', 'PNCPQ_FN', 'PNCQ', 'PNCQ_FN', 'PNCWIAPQ', 'PNCWIAPQ_FN', 'PNCWIAQ', 'PNCWIAQ_FN', 'PNCWIDPQ', 'PNCWIDPQ_FN', 'PNCWIDQ', 'PNCWIDQ_FN', 'PNCWIEPQ', 'PNCWIEPQ_FN', 'PNCWIEPSQ', 'PNCWIEPSQ_FN', 'PNCWIPPQ', 'PNCWIPQ', 'PPCQ', 'PPCQ_DC', 'PPCQ_FN', 'PPICQ', 'PPICQ_DC', 'PPICQ_FN', 'PPOPCCQ', 'PPOPCCQ_DC', 'PPOPCCQ_FN', 'PPRPAQ', 'PPRPAQ_DC', 'PPRPAQ_FN', 'PPSCQ', 'PPSCQ_DC', 'PPSCQ_FN', 'PRCAQ', 'PRCAQ_FN', 'PRCD12', 'PRCD12_FN', 'PRCDQ', 'PRCDQ_FN', 'PRCE12', 'PRCE12_FN', 'PRCEPS12', 'PRCEPS12_FN', 'PRCEPSQ', 'PRCEPSQ_FN', 'PRCPD12', 'PRCPD12_FN', 'PRCPDQ', 'PRCPDQ_FN', 'PRCPEPS12', 'PRCPEPS12_FN', 'PRCPEPSQ', 'PRCPEPSQ_FN', 'PRCPQ', 'PRCPQ_FN']
# - documents-export-2025-3-19/indexdatamonthly.parquet
#   columns (7): ['KYGVKEYX', 'DATADATE', 'DIVXM', 'XDVPSXM', 'XPRCCM', 'XPRCHM', 'XPRCLM']
# - documents-export-2025-3-19/exchangeratedaily.parquet
#   columns (4): ['KYCURRENCY', 'KEYSET_TAG', 'DATADATE', 'EXRATD']
# - documents-export-2025-3-19/bankyeartodate.parquet
#   columns (160): ['KYGVKEY', 'KEYSET', 'FYYYYQ', 'fyrq', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'AMGWY', 'AMGWY_DC', 'AOCOEY', 'AOCOEY_DC', 'AOCORY', 'AOCORY_DC', 'BMIIY', 'BMIIY_DC', 'COEITY', 'COEITY_DC', 'DATPY', 'DATPY_DC', 'DEPCHY', 'DEPCHY_DC', 'DINVCY', 'DINVCY_DC', 'DLRECY', 'DLRECY_DC', 'DVCY', 'DVCY_DC', 'FCCY', 'FCCY_DC', 'FDACY', 'FDACY_DC', 'FEDRCSY', 'FEDRCSY_DC', 'FEOENY', 'FEOENY_DC', 'FLSY', 'FLSY_DC', 'FOY', 'FOY_DC', 'GLOY', 'GLOY_DC', 'ICNDY', 'ICNDY_DC', 'IDBIY', 'IDBIY_DC', 'IDIISY', 'IDIISY_DC', 'IDILBCY', 'IDILBCY_DC', 'IDILBCY_FN', 'IDISY', 'IDISY_DC', 'IDITSY', 'IDITSY_DC', 'IDOTSY', 'IDOTSY_DC', 'IDOTSY_FN', 'IDTSY', 'IDTSY_DC', 'IFFSSPY', 'IFFSSPY_DC', 'IFFSSPY_FN', 'IINVCY', 'IINVCY_DC', 'ILRECY', 'ILRECY_DC', 'ILTDNCY', 'ILTDNCY_DC', 'INVSGLY', 'INVSGLY_DC', 'IOSPSY', 'IOSPSY_DC', 'IREOY', 'IREOY_DC', 'ISGACY', 'ISGACY_DC', 'ITACOEY', 'ITACOEY_DC', 'ITACOEY_FN', 'MIAFPIRY', 'MIAFPIRY_DC', 'NATPIRXY', 'NATPIRXY_DC', 'NATPIRY', 'NATPIRY_DC', 'NATPIRY_FN', 'NCOEACY', 'NCOEACY_DC', 'NCOEMIY', 'NCOEMIY_DC', 'NCOEPSFXY', 'NCOEPSFXY_DC', 'NCOEPSPXY', 'NCOEPSPXY_DC', 'NCOEPSPXY_FN', 'NCOEY', 'NCOEY_DC', 'NIADJY', 'NIADJY_DC', 'NIINTY', 'NIINTY_DC', 'NIIPLY', 'NIIPLY_DC', 'NREY', 'NREY_DC', 'NRIY', 'NRIY_DC', 'OCOEY', 'OCOEY_DC', 'OCORY', 'OCORY_DC', 'OEBPNY', 'OEBPNY_DC', 'OFAY', 'OGLOSY', 'OGLOSY_DC', 'ONIIY', 'ONIIY_DC', 'OTHOPY', 'PCLCY', 'PVOAY', 'PVOAY_DC', 'SCDAY', 'SCDAY_DC', 'SCECCY', 'SCECCY_DC', 'TAIY', 'TAIY_DC', 'TCOEY', 'TCOEY_DC', 'TCOEY_FN', 'TCORY', 'TCORY_DC', 'TCORY_FN', 'TEPLY', 'TEPLY_DC', 'TFY', 'TFY_DC', 'TNIIY', 'TNIIY_DC', 'TRBDIUPY', 'TRBDIUPY_DC', 'TXIIY', 'TXIIY_DC', 'XADY', 'XADY_DC', 'XFFPSSY', 'XFFPSSY_DC', 'XINDCY', 'XINDCY_DC', 'XINSY', 'XINSY_DC', 'XNITBY', 'XNITBY_DC', 'XOREOY', 'XOREOY_DC', 'XPRBY', 'XPRBY_DC', 'XSTFWSY', 'XSTFWSY_DC']
# - documents-export-2025-3-19/bankannual.parquet
#   columns (249): ['KYGVKEY', 'KEYSET', 'FYYYY', 'fyra', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'AAM', 'AHS', 'ALIR', 'AOCOE', 'AOCOR', 'AOE', 'AOE_DC', 'AOM', 'AONE', 'AOTD', 'ARBDDMA', 'AROL', 'AROL_DC', 'ATE', 'BMII', 'BMII_DC', 'BRCL', 'CDBI', 'CDBI_DC', 'CDBNI', 'CDBNI_DC', 'CDBT', 'CDBT_DC', 'CDBT_FN', 'CND', 'CND_DC', 'COC', 'COC_DC', 'COEIT', 'CPRLL', 'CSHA', 'CTTD', 'CTTD_DC', 'DATP', 'DATP_DC', 'DDIPC', 'DEPCH', 'DEPCH_DC', 'DFG', 'DIB', 'DIB_FN', 'DINVC', 'DINVC_DC', 'DLREC', 'DLREC_DC', 'DLTCC', 'DLTCC_DC', 'DNIB', 'DNIB_DC', 'DPRLL', 'DSPS', 'DUSG', 'DUSG_DC', 'FCC', 'FCC_DC', 'FDAC', 'FDAC_DC', 'FEDRCS', 'FEDRCS_DC', 'FEOEN', 'FEOEN_DC', 'FFPSS', 'FFPSS_DC', 'FFSSP', 'FFSSP_DC', 'FFSSP_FN', 'FHLB', 'FHLB_DC', 'FLS', 'FLS_DC', 'FO', 'FO_DC', 'GLO', 'GLO_DC', 'ICND', 'ICND_DC', 'IDBI', 'IDBI_DC', 'IDILBC', 'IDILBC_DC', 'IDILBC_FN', 'IDOTS', 'IDOTS_DC', 'IDOTS_FN', 'IDTS', 'IDTS_DC', 'IFFSSP', 'IFFSSP_DC', 'IFFSSP_FN', 'IINVC', 'IINVC_DC', 'ILREC', 'ILREC_DC', 'ILTDNC', 'ILTDNC_DC', 'INVSGL', 'INVSGL_DC', 'IOSPS', 'IOSPS_DC', 'IREO', 'IREO_DC', 'ISGAC', 'ISGAC_DC', 'ITACOE', 'ITACOE_FN', 'LAO', 'LAO_DC', 'LCACLD', 'LCACLD_DC', 'LCACLF', 'LCACLF_DC', 'LCACRD', 'LCACRD_DC', 'LCACRF', 'LCACRF_DC', 'LDT', 'LFT', 'LFT_DC', 'LFT_FN', 'LG', 'LG_DC', 'LGDLF', 'LHS', 'LHS_DC', 'LIB', 'LNDLF', 'LNDLF_DC', 'LNDLF_FN', 'LNIB', 'LNTAL', 'LNTAL_DC', 'LNTAL_FN', 'LOF', 'LOF_DC', 'LOIB', 'LPCS', 'LPCS_DC', 'LTMIB', 'MBSHS', 'MBSHS_DC', 'MIAFPIR', 'MIAFPIR_DC', 'MMCD', 'MMCD_DC', 'MTGI', 'MTGI_DC', 'NATPIR', 'NATPIR_DC', 'NATPIRX', 'NCOE', 'NCOEAC', 'NCOEMI', 'NCOEPSFX', 'NCOEPSFX_FN', 'NCOEPSPX', 'NCOEPSPX_FN', 'NDO', 'NFO', 'NFO_DC', 'NIIPL', 'NRE', 'NRE_DC', 'NRI', 'NRI_DC', 'NTXII', 'NTXII_DC', 'OAHS', 'OAHS_DC', 'OBCP', 'OBCP_DC', 'OCOE', 'OCOR', 'OCOR_DC', 'OD', 'OD_FN', 'OEBPN', 'OEBPN_DC', 'OFA', 'OGLOS', 'OGLOS_DC', 'OLBM', 'OLBM_DC', 'ONII', 'ONII_DC', 'OSPS', 'OSPS_DC', 'OST', 'OST_DC', 'OST_FN', 'OTHOP', 'PCLC', 'PSHO', 'PSHO_DC', 'RCOCR', 'RCOCR_DC', 'RECINT', 'RECINT_DC', 'RELIGG', 'RELIGG_DC', 'RS', 'SCDA', 'SCDA_DC', 'SCECC', 'SCECC_DC', 'SHS', 'SHS_DC', 'SOUSGA', 'SOUSGA_DC', 'TAI', 'TAI_DC', 'TB', 'TB_DC', 'TB_FN', 'TCOE', 'TCOE_FN', 'TCOR', 'TCOR_FN', 'TDOMD', 'TEPL', 'TEPL_DC', 'TFD', 'TFD_DC', 'TNII', 'TRBDIUP', 'TRLS', 'TSDIPC', 'TSDIPC_DC', 'TTIS', 'TTIS_DC', 'TXII', 'TXTEQ', 'TXTEQ_FN', 'UIT', 'USTS', 'USTS_DC', 'XFFPSS', 'XFFPSS_DC', 'XINTDB', 'XOREO', 'XOREO_DC', 'XPRB', 'XPRB_DC']
# - documents-export-2025-3-19/perioddescriptorannual.parquet
#   columns (37): ['KYGVKEY', 'KEYSET', 'FYYYY', 'fyra', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'ACCTCHG', 'ACCTSTD', 'ACQMETH', 'ADRR', 'AJEX', 'AJP', 'APDEDATE', 'BSPR', 'COMPST', 'CURCD', 'CURNCD', 'CURRTR', 'CURUSCN', 'FDATE', 'FINAL', 'FYEAR', 'FYR', 'ISMOD', 'LTCM', 'LTDD', 'NAICSH', 'OGM', 'PDATE', 'PDDUR', 'SCF', 'SICH', 'SRC', 'STALT', 'UDPL', 'UPD']
# - documents-export-2025-3-19/operatingsegmentcustomer.parquet
#   columns (14): ['KYGVKEY', 'SC_SRCYR', 'SC_SRCFYR', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'SC_CSTYPE', 'SC_CSID', 'SC_CDID', 'SC_CSALE', 'SC_CTYPE', 'SC_CGEOCD', 'SC_CGEOAR', 'SC_CNAME']
# - documents-export-2025-3-19/linkfiscalytddefault.parquet
#   columns (20): ['KYGVKEY', 'fiscalperiod', 'FiscalYearEndMonthNbr', 'FiscalPeriodTypeCd', 'linkrank', 'FiscalPeriodStartDt', 'FiscalPeriodEndDt', 'lpermno', 'lpermco', 'liid', 'LinkRangeTypeCd', 'linktype', 'linkprim', 'LinkMadeCnt', 'LinkPERMNOCnt', 'LinkNonZeroPERMNOCnt', 'FiscalPeriodCRSPStartDt', 'FiscalPeriodCRSPEndDt', 'linkdt', 'linkenddt']
# - documents-export-2025-3-19/operatingsegmentdetail.parquet
#   columns (12): ['KYGVKEY', 'SD_SRCYR', 'SD_SRCFYR', 'lpermno', 'lpermco', 'LinkRangeTypeCd', 'SD_STYPE', 'SD_SID', 'SD_SOPTP1', 'SD_SOPTP2', 'SD_SGEOTP', 'SD_SNAME']
# - documents-export-2025-3-19/linkfiscalquarterlydefault.parquet
#   columns (20): ['KYGVKEY', 'fiscalperiod', 'FiscalYearEndMonthNbr', 'FiscalPeriodTypeCd', 'linkrank', 'FiscalPeriodStartDt', 'FiscalPeriodEndDt', 'lpermno', 'lpermco', 'liid', 'LinkRangeTypeCd', 'linktype', 'linkprim', 'LinkMadeCnt', 'LinkPERMNOCnt', 'LinkNonZeroPERMNOCnt', 'FiscalPeriodCRSPStartDt', 'FiscalPeriodCRSPEndDt', 'linkdt', 'linkenddt']
# - documents-export-2025-3-19/balancesheetfinancialannual.parquet
# ...
# - documents-export-2025-3-19(1)/sfz_dp_dly.parquet
#   columns (7): ['KYPERMNO', 'CALDT', 'PRC', 'RET', 'RETX', 'TCAP', 'VOL']
# - documents-export-2025-3-19(1)/sfz_ds_dly.parquet
#   columns (8): ['KYPERMNO', 'CALDT', 'BIDLO', 'ASKHI', 'BID', 'ASK', 'NUMTRD', 'OPENPRC']
# - documents-export-2025-3-19(1)/sfz_agg_mth.parquet
#   columns (31): ['KYPERMNO', 'YYYYMM', 'MCALDT', 'MTHPRC', 'MTHPRCFLG', 'MTHPRCDT', 'MTHDTFLG', 'MTHDELFLG', 'MTHCAP', 'MTHPREVPRC', 'MTHPREVPRCFLG', 'MTHPREVDT', 'MTHPREVDTFLG', 'MTHPREVCAP', 'MTHRET', 'MTHRETX', 'MTHRETFLG', 'MTHDISCNT', 'MTHVOL', 'MTHVOLFLG', 'MTHPRCVOL', 'MTHFACSHRFLG', 'MTHPRCVOLMISSCNT', 'NCUSIP', 'TICKER', 'COMNAM', 'SHRCD', 'NMSIND', 'PRIMEXCH', 'TRDSTAT', 'SECSTAT']
# - documents-export-2025-3-19(1)/sfz_mth.parquet
#   columns (14): ['KYPERMNO', 'MCALDT', 'MPRC', 'MRET', 'MRETX', 'MTCAP', 'MVOL', 'MBIDLO', 'MASKHI', 'MBID', 'MASK', 'MSPREAD', 'MALTPRC', 'MALTPRCDT']
# - documents-export-2025-3-19(1)/sfz_agg_qtr.parquet
#   columns (31): ['KYPERMNO', 'YYYYQ', 'QCALDT', 'QTRPRC', 'QTRPRCFLG', 'QTRPRCDT', 'QTRDTFLG', 'QTRDELFLG', 'QTRCAP', 'QTRPREVPRC', 'QTRPREVPRCFLG', 'QTRPREVDT', 'QTRPREVDTFLG', 'QTRPREVCAP', 'QTRRET', 'QTRRETX', 'QTRRETFLG', 'QTRDISCNT', 'QTRVOL', 'QTRVOLFLG', 'QTRPRCVOL', 'QTRFACSHRFLG', 'QTRPRCVOLMISSCNT', 'NCUSIP', 'TICKER', 'COMNAM', 'SHRCD', 'NMSIND', 'PRIMEXCH', 'TRDSTAT', 'SECSTAT']
# - documents-export-2025-3-19(1)/sfz_agg_ann.parquet
#   columns (31): ['KYPERMNO', 'YYYY', 'ACALDT', 'ANNPRC', 'ANNPRCFLG', 'ANNPRCDT', 'ANNDTFLG', 'ANNDELFLG', 'ANNCAP', 'ANNPREVPRC', 'ANNPREVPRCFLG', 'ANNPREVDT', 'ANNPREVDTFLG', 'ANNPREVCAP', 'ANNRET', 'ANNRETX', 'ANNRETFLG', 'ANNDISCNT', 'ANNVOL', 'ANNVOLFLG', 'ANNPRCVOL', 'ANNFACSHRFLG', 'ANNPRCVOLMISSCNT', 'NCUSIP', 'TICKER', 'COMNAM', 'SHRCD', 'NMSIND', 'PRIMEXCH', 'TRDSTAT', 'SECSTAT']
# - documents-export-2025-3-19(1)/sfz_ndi.parquet
#   columns (7): ['KYPERMNO', 'TRTSDT', 'TRTSENDDT', 'NSDINX', 'NMSIND', 'MMCNT', 'TRTSCD']
# - documents-export-2025-3-19(1)/sfz_nam.parquet
#   columns (16): ['KYPERMNO', 'NAMEDT', 'NAMEENDDT', 'NCUSIP', 'NCUSIP9', 'TICKER', 'COMNAM', 'SHRCLS', 'SHRCD', 'EXCHCD', 'SICCD', 'TSYMBOL', 'SNAICS', 'PRIMEXCH', 'TRDSTAT', 'SECSTAT']
# - documents-export-2025-3-19(1)/sfz_dind.parquet
#   columns (12): ['KYINDNO', 'CALDT', 'TRET', 'TIND', 'ARET', 'AIND', 'IRET', 'IIND', 'USDCNT', 'USDVAL', 'TOTCNT', 'TOTVAL']
# - documents-export-2025-3-19(1)/sfz_dis.parquet
#   columns (11): ['KYPERMNO', 'DISTCD', 'DIVAMT', 'FACPR', 'FACSHR', 'DCLRDT', 'EXDT', 'RCRDDT', 'PAYDT', 'ACPERM', 'ACCOMP']
# - documents-export-2025-3-19(1)/sfz_shr.parquet
#   columns (5): ['KYPERMNO', 'SHRSDT', 'SHRSENDDT', 'SHROUT', 'SHRFLG']
# - documents-export-2025-3-19(1)/sfz_del.parquet
#   columns (11): ['KYPERMNO', 'DLSTDT', 'DLSTCD', 'NWPERM', 'NWCOMP', 'NEXTDT', 'DLPRC', 'DLPDT', 'DLAMT', 'DLRET', 'DLRETX']
# - documents-export-2025-3-19(1)/sfz_mind.parquet
#   columns (12): ['KYINDNO', 'MCALDT', 'MTRET', 'MTIND', 'MARET', 'MAIND', 'MIRET', 'MIIND', 'MUSDCNT', 'MUSDVAL', 'MTOTCNT', 'MTOTVAL']
# - documents-export-2025-3-19(1)/sfz_mdel.parquet
#   columns (11): ['KYPERMNO', 'MDLSTDT', 'MDLSTCD', 'MNWPERM', 'MNWCOMP', 'MNEXTDT', 'MDLPRC', 'MDLPDT', 'MDLAMT', 'MDLRET', 'MDLRETX']
# - documents-export-2025-3-19(1)/sfz_hdr.parquet
#   columns (19): ['KYPERMNO', 'CUSIP', 'CUSIP9', 'HTICK', 'PERMCO', 'COMPNO', 'ISSUNO', 'HEXCD', 'HSICCD', 'BEGDT', 'ENDDT', 'HDLSTCD', 'HCOMNAM', 'HTSYMBOL', 'HSNAICS', 'HSHRCD', 'HPRIMEXCH', 'HTRDSTAT', 'HSECSTAT']
# - documents-export-2025-3-19(1)/sfz_indhdr.parquet
#   columns (15): ['KYINDNO', 'INDNAME', 'INDBEGDT', 'INDENDDT', 'INDFAM', 'PORTNUM', 'BASELVL', 'BASEDT', 'AVAILABILITY', 'CALCRULE', 'LISTRULE', 'METHOD', 'REBALRULE', 'PUNIVERSE', 'UNIVERSE']
# - documents-export-2025-3-19(2)/StkDlySecurityData.parquet
#   columns (32): ['PERMNO', 'YYYYMMDD', 'DlyCalDt', 'DlyDelFlg', 'DlyPrc', 'DlyPrcFlg', 'DlyCap', 'DlyCapFlg', 'DlyPrevPrc', 'DlyPrevPrcFlg', 'DlyPrevDt', 'DlyPrevCap', 'DlyPrevCapFlg', 'DlyRet', 'DlyRetx', 'DlyRetI', 'DlyRetMissFlg', 'DlyRetDurFlg', 'DlyOrdDivAmt', 'DlyNonOrdDivAmt', 'DlyFacPrc', 'DlyDistRetFlg', 'DlyVol', 'DlyClose', 'DlyLow', 'DlyHigh', 'DlyBid', 'DlyAsk', 'DlyOpen', 'DlyNumTrd', 'DlyMMCnt', 'DlyPrcVol']
# - documents-export-2025-3-19(2)/StkDlySecurityPrimaryData.parquet
#   columns (12): ['PERMNO', 'DlyCalDt', 'DlyDelFlg', 'DlyPrc', 'DlyPrcFlg', 'DlyCap', 'DlyCapFlg', 'DlyRet', 'DlyRetx', 'DlyRetMissFlg', 'DlyDistRetFlg', 'DlyVol']
# - documents-export-2025-3-19(2)/StkDlyCumulativeAdjFactor.parquet
#   columns (5): ['PERMNO', 'DlyCalDt', 'DlyShrOut', 'DlyCumFacPr', 'DlyCumFacShr']
# - documents-export-2025-3-19(2)/StkMthSecurityData.parquet
#   columns (37): ['PERMNO', 'YYYYMM', 'MthCalDt', 'MthCompFlg', 'MthCompSubFlg', 'MthPrc', 'MthPrcFlg', 'MthPrcDt', 'MthDtFlg', 'MthDelFlg', 'MthCap', 'MthPrevPrc', 'MthPrevPrcFlg', 'MthPrevDt', 'MthPrevDtFlg', 'MthPrevCap', 'MthRet', 'MthRetx', 'MthRetFlg', 'MthDisCnt', 'MthVol', 'MthVolFlg', 'MthPrcVol', 'MthFacShrFlg', 'MthPrcVolMissCnt', 'CUSIP', 'Ticker', 'IssuerNm', 'USIncFlg', 'IssuerType', 'SecurityType', 'SecuritySubType', 'ShareType', 'ExchangeTier', 'PrimaryExch', 'TradingStatusFlg', 'ConditionalType']
# - documents-export-2025-3-19(2)/StkAnnSecurityData.parquet
#   columns (37): ['PERMNO', 'YYYY', 'AnnCalDt', 'AnnCompFlg', 'AnnCompSubFlg', 'AnnPrc', 'AnnPrcFlg', 'AnnPrcDt', 'AnnDtFlg', 'AnnDelFlg', 'AnnCap', 'AnnPrevPrc', 'AnnPrevPrcFlg', 'AnnPrevDt', 'AnnPrevDtFlg', 'AnnPrevCap', 'AnnRet', 'AnnRetx', 'AnnRetFlg', 'AnnDisCnt', 'AnnVol', 'AnnVolFlg', 'AnnPrcVol', 'AnnFacShrFlg', 'AnnPrcVolMissCnt', 'CUSIP', 'Ticker', 'IssuerNm', 'USIncFlg', 'IssuerType', 'SecurityType', 'SecuritySubType', 'ShareType', 'ExchangeTier', 'PrimaryExch', 'TradingStatusFlg', 'ConditionalType']
# - documents-export-2025-3-19(2)/StkDistributions.parquet
#   columns (19): ['PERMNO', 'DisExDt', 'DisSeqNbr', 'DisOrdinaryFlg', 'DisType', 'DisFreqType', 'DisPaymentType', 'DisDetailType', 'DisTaxType', 'DisOrigCurType', 'DisDivAmt', 'DisFacPr', 'DisFacShr', 'DisDeclareDt', 'DisRecordDt', 'DisPayDt', 'DisPERMNO', 'DisPERMCO', 'DisAmountSourceType']
# - documents-export-2025-3-19(2)/StkMthFloatShares.parquet
#   columns (4): ['PERMNO', 'YYYYMM', 'MthFloatShrQty', 'MthFloatShrPct']
# - documents-export-2025-3-19(2)/StkShares.parquet
#   columns (7): ['PERMNO', 'ShrStartDt', 'ShrEndDt', 'ShrOut', 'ShrSource', 'ShrFacType', 'ShrAdrFlg']
# - documents-export-2025-3-19(2)/StkQtrSecurityData.parquet
#   columns (37): ['PERMNO', 'YYYYQ', 'QtrCalDt', 'QtrCompFlg', 'QtrCompSubFlg', 'QtrPrc', 'QtrPrcFlg', 'QtrPrcDt', 'QtrDtFlg', 'QtrDelFlg', 'QtrCap', 'QtrPrevPrc', 'QtrPrevPrcFlg', 'QtrPrevDt', 'QtrPrevDtFlg', 'QtrPrevCap', 'QtrRet', 'QtrRetx', 'QtrRetFlg', 'QtrDisCnt', 'QtrVol', 'QtrVolFlg', 'QtrPrcVol', 'QtrFacShrFlg', 'QtrPrcVolMissCnt', 'CUSIP', 'Ticker', 'IssuerNm', 'USIncFlg', 'IssuerType', 'SecurityType', 'SecuritySubType', 'ShareType', 'ExchangeTier', 'PrimaryExch', 'TradingStatusFlg', 'ConditionalType']
# - documents-export-2025-3-19(2)/MetaColumnCoverage.parquet
#   columns (14): ['FileName', 'ColPosition', 'ItemName', 'ColCount', 'ColCountId', 'ColMinDt', 'ColMaxDt', 'ColCountPct', 'ColCountIdPct', 'ColDatePct', 'ColumnKey', 'FileKey', 'ItemKey', 'ColCoverageKey']
# - documents-export-2025-3-19(2)/StkMthCumulativeAdjFactor.parquet
#   columns (5): ['PERMNO', 'MthCalDt', 'MthShrOut', 'MthCumFacPr', 'MthCumFacShr']
# - documents-export-2025-3-19(2)/StkSecurityInfoHist.parquet
#   columns (36): ['PERMNO', 'SecInfoStartDt', 'SecInfoEndDt', 'SecurityBegDt', 'SecurityEndDt', 'SecurityHdrFlg', 'HdrCUSIP', 'HdrCUSIP9', 'CUSIP', 'CUSIP9', 'PrimaryExch', 'ConditionalType', 'ExchangeTier', 'TradingStatusFlg', 'SecurityNm', 'ShareClass', 'USIncFlg', 'IssuerType', 'SecurityType', 'SecuritySubType', 'ShareType', 'SecurityActiveFlg', 'DelActionType', 'DelStatusType', 'DelReasonType', 'DelPaymentType', 'Ticker', 'TradingSymbol', 'PERMCO', 'SICCD', 'NAICS', 'ICBIndustry', 'UESIndustry', 'NASDCompno', 'NASDIssuno', 'IssuerNm']
# - documents-export-2025-3-19(2)/MetaColumnInfo.parquet
#   columns (14): ['FileName', 'ColPosition', 'ItemName', 'ColNullFlg', 'ColSQLDataType', 'ColSASDataType', 'ColSASDisplayFormat', 'ColSASExportFormat', 'ColASCIIMaxFieldSize', 'ColRDataType', 'ColCoverageFlg', 'ColumnKey', 'FileKey', 'ItemKey']
# - documents-export-2025-3-19(2)/MetaItemInfo.parquet
#   columns (13): ['ItemName', 'ItemDesc', 'ItemDef', 'ItemCategory', 'ItemClass', 'ItemMaxCharLen', 'ItemNullFlg', 'ItemMissingFlg', 'ItemHasDataFlg', 'ItemFlagType', 'ItemActiveFlg', 'ItemFileCnt', 'ItemKey']
# - documents-export-2025-3-19(2)/MetaExchangeCalendar.parquet
#   columns (7): ['CalDt', 'TradingFlg', 'HolidayFlg', 'WeekendFlg', 'DateStatusFlg', 'Weekday', 'ExchangeGroup']
# - documents-export-2025-3-19(2)/StkDelists.parquet
#   columns (19): ['PERMNO', 'DelistingDt', 'DelDtPrc', 'DelDtPrcFlg', 'DelActionType', 'DelStatusType', 'DelReasonType', 'DelPaymentType', 'DelPERMNO', 'DelPERMCO', 'DelRet', 'DelRetMissType', 'DelNextDt', 'DelNextPrc', 'DelNextPrcFlg', 'DelAmtDt', 'DelDivAmt', 'DelDisType', 'DelDlyDt']
# - documents-export-2025-3-19(2)/StkIssuerInfoHist.parquet
#   columns (18): ['PERMCO', 'IssInfoStartDt', 'IssInfoEndDt', 'IssuerBegDt', 'IssuerEndDt', 'IssuerHdrFlg', 'CNUM', 'IssuerNm', 'SecurityRangeCnt', 'SecurityTotalCnt', 'USIncFlg', 'IssuerType', 'IssuerStatusType', 'SICCD', 'NAICS', 'ICBIndustry', 'UESIndustry', 'NASDCompno']
# - documents-export-2025-3-19(2)/MetaFileInfo.parquet
#   columns (19): ['FileName', 'FileDesc', 'FileDef', 'FileCategory', 'FileRowFreq', 'FileColumnCnt', 'FileDataColumnCnt', 'FileKeyCnt', 'FileKeyType', 'FileItemName1', 'FileItemName2', 'FileItemName3', 'FileItemName4', 'FileActiveFlg', 'FileKey', 'FileItemKey1', 'FileItemKey2', 'FileItemKey3', 'FileItemKey4']
# - documents-export-2025-3-19(2)/MetaFlagType.parquet
#   columns (6): ['FlagType', 'FlagTypeDesc', 'FlagTypeItemCnt', 'FlagTypeColumnCnt', 'FlagTypeDef', 'FlagTypeKey']
# - documents-export-2025-3-19(2)/StkIssuerInfoHdr.parquet
#   columns (18): ['PERMCO', 'IssInfoStartDt', 'IssInfoEndDt', 'IssuerBegDt', 'IssuerEndDt', 'IssuerHdrFlg', 'CNUM', 'IssuerNm', 'SecurityRangeCnt', 'SecurityTotalCnt', 'USIncFlg', 'IssuerType', 'IssuerStatusType', 'SICCD', 'NAICS', 'ICBIndustry', 'UESIndustry', 'NASDCompno']
# - documents-export-2025-3-19(2)/MetaSIZtoCIZ.parquet
#   columns (14): ['SIZFileName', 'SIZColPosition', 'SIZColMapSeq', 'SIZItemName', 'SIZItemDesc', 'CIZFileName', 'CIZItemName', 'CIZItemDesc', 'SIZMappingType', 'SIZMappingSubType', 'CIZColumnKey', 'CIZFileKey', 'CIZItemKey', 'SIZColumnMappingKey']
# - documents-export-2025-3-19(2)/IndFamilyInfoHdr.parquet
#   columns (23): ['INDFAM', 'IndFamType', 'IndFamNm', 'IndFamBegDt', 'IndFamEndDt', 'BaseLvl', 'BaseDt', 'FreqAvail', 'WeightType', 'CntValType', 'UniverseType', 'ExchangeGroup', 'IndFamSize', 'IndFamFirstINDNO', 'IndFamLastINDNO', 'UnderlyingDataCd', 'PortOrder', 'AssignStatType', 'BreakpointFormType', 'BreakpointStatType', 'BreakpointFreqType', 'BetaStatMrktINDNO', 'BreakpointINDFAM']
# - documents-export-2025-3-19(2)/IndMthSeriesData.parquet
#   columns (15): ['INDNO', 'YYYYMM', 'MthCalDt', 'MthTotRet', 'MthTotInd', 'MthPrcRet', 'MthPrcInd', 'MthIncRet', 'MthIncInd', 'MthUsdCnt', 'MthUsdVal', 'MthTotCnt', 'MthTotVal', 'MthEligCnt', 'MthWgtAmt']
# - documents-export-2025-3-19(2)/IndDlySeriesData.parquet
#   columns (15): ['INDNO', 'YYYYMMDD', 'DlyCalDt', 'DlyTotRet', 'DlyTotInd', 'DlyPrcRet', 'DlyPrcInd', 'DlyIncRet', 'DlyIncInd', 'DlyUsdCnt', 'DlyUsdVal', 'DlyTotCnt', 'DlyTotVal', 'DlyEligCnt', 'DlyWgtAmt']
# - documents-export-2025-3-19(2)/MetaFlagCoverage.parquet
#   columns (18): ['FileName', 'ColPosition', 'ItemName', 'FlagType', 'FlagValue', 'FlagDesc', 'FlagCount', 'FlagCountId', 'FlagMinDt', 'FlagMaxDt', 'FlagCountPct', 'FlagCountIdPct', 'FlagDatePct', 'ColumnKey', 'FileKey', 'ItemKey', 'FlagKey', 'FlagCoverageKey']
# - documents-export-2025-3-19(2)/MetaFlagInfo.parquet
#   columns (7): ['FlagType', 'FlagValue', 'FlagTypeDesc', 'FlagDesc', 'FlagDef', 'FlagCoverageFlg', 'FlagKey']
# - documents-export-2025-3-19(2)/StkSecurityInfoHdr.parquet
#   columns (36): ['PERMNO', 'SecInfoStartDt', 'SecInfoEndDt', 'SecurityBegDt', 'SecurityEndDt', 'SecurityHdrFlg', 'HdrCUSIP', 'HdrCUSIP9', 'CUSIP', 'CUSIP9', 'PrimaryExch', 'ConditionalType', 'ExchangeTier', 'TradingStatusFlg', 'SecurityNm', 'ShareClass', 'USIncFlg', 'IssuerType', 'SecurityType', 'SecuritySubType', 'ShareType', 'SecurityActiveFlg', 'DelActionType', 'DelStatusType', 'DelReasonType', 'DelPaymentType', 'Ticker', 'TradingSymbol', 'PERMCO', 'SICCD', 'NAICS', 'ICBIndustry', 'UESIndustry', 'NASDCompno', 'NASDIssuno', 'IssuerNm']
# - documents-export-2025-3-19(2)/MetaCalendarPeriod.parquet
#   columns (14): ['CalPeriodKey', 'CalPeriodType', 'CalPeriodStartDt', 'CalPeriodEndDt', 'CalPeriodCRSPStartDt', 'CalPeriodCRSPEndDt', 'CalPeriodNextKey', 'CalPeriodPrevKey', 'CalPeriodPrevEndDt', 'CalPeriodPrevCRSPEndDt', 'CalPeriodNbr', 'CalPeriodDayCnt', 'CalPeriodCRSPDayCnt', 'CalPeriodFlg']
# - documents-export-2025-3-19(2)/IndSeriesInfoHdr.parquet
#   columns (12): ['INDNO', 'INDFAM', 'IndFamType', 'IndNm', 'IndBegDt', 'IndEndDt', 'BaseLvl', 'BaseDt', 'FreqAvail', 'WeightType', 'CntValType', 'PortNum']
# - derived_data/temp_step1_sec_merge.parquet
#   columns (43): ['KYPERMNO', 'CALDT', 'PRC', 'RET', 'RETX', 'TCAP', 'VOL', 'BIDLO', 'ASKHI', 'BID', 'ASK', 'NUMTRD', 'OPENPRC', 'data_status', 'DLSTDT', 'DLSTCD', 'DLPRC', 'DLAMT', 'DLRET', 'DLRETX', 'FINAL_RET', 'FINAL_RETX', 'FINAL_PRC', 'SRCTYPE_all', 'FILEDATE_all', 'FILEDATETIME_all', 'n_filings', 'LIID', 'LINKDT', 'LINKENDDT', 'LINKTYPE', 'LINKPRIM', 'is_canonical_link', 'valid_link', 'link_rank_base', 'link_rank', 'KYGVKEY_ccm', 'KYGVKEY_final', 'link_quality_flag', 'HIST_START_DATE_SEC', 'HCHGENDDT_SEC', 'HTPCI', 'HEXCNTRY']
# - derived_data/final_flagged_data.parquet
#   columns (49): ['KYPERMNO', 'CALDT', 'PRC', 'RET', 'RETX', 'TCAP', 'VOL', 'BIDLO', 'ASKHI', 'BID', 'ASK', 'NUMTRD', 'OPENPRC', 'data_status', 'DLSTDT', 'DLSTCD', 'DLPRC', 'DLAMT', 'DLRET', 'DLRETX', 'FINAL_RET', 'FINAL_RETX', 'FINAL_PRC', 'SRCTYPE_all', 'FILEDATE_all', 'FILEDATETIME_all', 'n_filings', 'LIID', 'LINKDT', 'LINKENDDT', 'LINKTYPE', 'LINKPRIM', 'is_canonical_link', 'valid_link', 'link_rank_base', 'link_rank', 'KYGVKEY_ccm', 'KYGVKEY_final', 'link_quality_flag', 'HIST_START_DATE_SEC', 'HCHGENDDT_SEC', 'HTPCI', 'HEXCNTRY', 'HIST_START_DATE_COMP', 'HCHGENDDT_COMP', 'HCIK', 'HSIC', 'HNAICS', 'HGSUBIND']
# - derived_data/final_flagged_data_compdesc_added.parquet
#   columns (53): ['KYPERMNO', 'CALDT', 'PRC', 'RET', 'RETX', 'TCAP', 'VOL', 'BIDLO', 'ASKHI', 'BID', 'ASK', 'NUMTRD', 'OPENPRC', 'data_status', 'DLSTDT', 'DLSTCD', 'DLPRC', 'DLAMT', 'DLRET', 'DLRETX', 'FINAL_RET', 'FINAL_RETX', 'FINAL_PRC', 'SRCTYPE_all', 'FILEDATE_all', 'FILEDATETIME_all', 'n_filings', 'LIID', 'LINKDT', 'LINKENDDT', 'LINKTYPE', 'LINKPRIM', 'is_canonical_link', 'valid_link', 'link_rank_base', 'link_rank', 'KYGVKEY_ccm', 'KYGVKEY_final', 'link_quality_flag', 'HIST_START_DATE_SEC', 'HCHGENDDT_SEC', 'HTPCI', 'HEXCNTRY', 'HIST_START_DATE_COMP', 'HCHGENDDT_COMP', 'HCIK', 'HSIC', 'HNAICS', 'HGSUBIND', 'CIK_desc_10', 'n_cik_desc_uniq', 'HCIK_10', 'CIK_final']
# - derived_data/final_flagged_data_compdesc_added.firms_10pct_seed42_compdesc.parquet
#   columns (1): ['KYPERMNO']
# - derived_data/final_flagged_data_compdesc_added.sample_10pct_seed42_compdesc.parquet
#   columns (53): ['KYPERMNO', 'CALDT', 'PRC', 'RET', 'RETX', 'TCAP', 'VOL', 'BIDLO', 'ASKHI', 'BID', 'ASK', 'NUMTRD', 'OPENPRC', 'data_status', 'DLSTDT', 'DLSTCD', 'DLPRC', 'DLAMT', 'DLRET', 'DLRETX', 'FINAL_RET', 'FINAL_RETX', 'FINAL_PRC', 'SRCTYPE_all', 'FILEDATE_all', 'FILEDATETIME_all', 'n_filings', 'LIID', 'LINKDT', 'LINKENDDT', 'LINKTYPE', 'LINKPRIM', 'is_canonical_link', 'valid_link', 'link_rank_base', 'link_rank', 'KYGVKEY_ccm', 'KYGVKEY_final', 'link_quality_flag', 'HIST_START_DATE_SEC', 'HCHGENDDT_SEC', 'HTPCI', 'HEXCNTRY', 'HIST_START_DATE_COMP', 'HCHGENDDT_COMP', 'HCIK', 'HSIC', 'HNAICS', 'HGSUBIND', 'CIK_desc_10', 'n_cik_desc_uniq', 'HCIK_10', 'CIK_final']

# %%
# Cell 6

filenames = [
    'filingdates.parquet',
    'perioddescriptorquarterly.parquet',
    'perioddescriptorannual.parquet',
    'linkhistory.parquet',
    'linkfiscalperiodall.parquet',
    'companydescription.parquet',
    'securityheader.parquet',
    'securityheaderhistory.parquet',
    'balancesheetindustrialannual.parquet',
    'incomestatementindustrialannual.parquet',
    'cashflowannual.parquet',
    'companyhistory.parquet',
    'sfz_dp_dly.parquet',
    'sfz_ds_dly.parquet',
    'sfz_del.parquet',
    'sfz_dis.parquet',
    'sfz_nam.parquet',
    'sfz_hdr.parquet',
    # 'final_pit_data.parquet', # only read when it already exists (== code ran before already)
    # 'final_flagged_data.parquet', # only read when it already exists (== code ran before already)
]

BASE_DIR = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/parquet_data')

BASE_DIR2 = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/')
TARGET_FOLDERS = [
    'documents-export-2025-3-19',
    'documents-export-2025-3-19(1)',
    'documents-export-2025-3-19(2)',
    'derived_data',
]


# dict: { "filingdates": LazyFrame, ... }
tables: dict[str, pl.LazyFrame] = {}

for sub in TARGET_FOLDERS:
    if sub == 'derived_data':
      BASE_DIR_temp = BASE_DIR2
      # print(BASE_DIR_temp)
    else:
      BASE_DIR_temp = BASE_DIR
    folder = BASE_DIR_temp / sub
    if not folder.exists():
        print(f"[warn] missing folder: {folder}")
        continue

    for p in folder.rglob("*.parquet"):
        if sub == 'derived_data':
          print(p)
        if p.name not in filenames:
            continue

        key = p.stem  # e.g. "filingdates" from "filingdates.parquet"

        # optional: skip if we already loaded this file from another folder
        if key in tables:
            continue

        try:
            tables[key] = pl.scan_parquet(p)
            print(f"[ok] loaded {key} from {p.relative_to(BASE_DIR_temp)}")
        except Exception as e:
            print(f"[err] {p.relative_to(BASE_DIR_temp)} -> schema read failed: {e}")
# Out:
# [ok] loaded balancesheetindustrialannual from documents-export-2025-3-19/balancesheetindustrialannual.parquet
# [ok] loaded incomestatementindustrialannual from documents-export-2025-3-19/incomestatementindustrialannual.parquet
# [ok] loaded cashflowannual from documents-export-2025-3-19/cashflowannual.parquet
# [ok] loaded companyhistory from documents-export-2025-3-19/companyhistory.parquet
# [ok] loaded linkfiscalperiodall from documents-export-2025-3-19/linkfiscalperiodall.parquet
# [ok] loaded filingdates from documents-export-2025-3-19/filingdates.parquet
# [ok] loaded perioddescriptorquarterly from documents-export-2025-3-19/perioddescriptorquarterly.parquet
# [ok] loaded perioddescriptorannual from documents-export-2025-3-19/perioddescriptorannual.parquet
# [ok] loaded companydescription from documents-export-2025-3-19/companydescription.parquet
# [ok] loaded securityheaderhistory from documents-export-2025-3-19/securityheaderhistory.parquet
# [ok] loaded linkhistory from documents-export-2025-3-19/linkhistory.parquet
# [ok] loaded securityheader from documents-export-2025-3-19/securityheader.parquet
# [ok] loaded sfz_dp_dly from documents-export-2025-3-19(1)/sfz_dp_dly.parquet
# [ok] loaded sfz_ds_dly from documents-export-2025-3-19(1)/sfz_ds_dly.parquet
# [ok] loaded sfz_nam from documents-export-2025-3-19(1)/sfz_nam.parquet
# [ok] loaded sfz_dis from documents-export-2025-3-19(1)/sfz_dis.parquet
# [ok] loaded sfz_del from documents-export-2025-3-19(1)/sfz_del.parquet
# [ok] loaded sfz_hdr from documents-export-2025-3-19(1)/sfz_hdr.parquet
# /content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/temp_step1_sec_merge.parquet
# /content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data.parquet
# /content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data_compdesc_added.parquet
# /content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data_compdesc_added.firms_10pct_seed42_compdesc.parquet
# /content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data_compdesc_added.sample_10pct_seed42_compdesc.parquet

# %%
from thesis_pkg.pipeline import load_tables, merge_histories, build_price_panel, attach_filings, add_final_returns, attach_ccm_links
from pathlib import Path

# 1. Config
BASE_DIR = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/parquet_data')
BASE_DIR2 = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/')
TEMP_DIR = BASE_DIR2 / 'derived_data'

filenames = {
    'filingdates',
    'perioddescriptorquarterly',
    'perioddescriptorannual',
    'linkhistory',
    'linkfiscalperiodall',
    'companydescription',
    'securityheader',
    'securityheaderhistory',
    'balancesheetindustrialannual',
    'incomestatementindustrialannual',
    'cashflowannual',
    'companyhistory',
    'sfz_dp_dly',
    'sfz_ds_dly',
    'sfz_del',
    'sfz_dis',
    'sfz_nam',
    'sfz_hdr',
}

forms_10k_10q = [
    "10-K", "10-K/A", "10-KA",          # include both conventions
    "10-Q", "10-Q/A", "10-QA",
    "10-KT", "10-KT/A",
    "10-QT", "10-QT/A",
    "10-K405",                          # legacy
]

# 2. Load
# tables = load_tables([BASE_DIR], wanted={"sfz_dp_dly", "sfz_del", "companyhistory", ...})
tables = load_tables([BASE_DIR], wanted=filenames)

# 3. Run Pipeline
price_lf = build_price_panel(tables['sfz_ds_dly'], tables['sfz_dp_dly'], tables['sfz_del'], "1990-01-01")
price_returns_lf = add_final_returns(price_lf)
price_filings_lf = attach_filings(price_returns_lf, tables['filingdates'], forms_10k_10q) #["10-K", "10-Q", "10-KA", "10-QA"])
price_linked_lf = attach_ccm_links(price_filings_lf, tables['linkhistory'])
# 4. The "Big Merge" (RAM Safe)
final_path = merge_histories(
    price_linked_lf,
    tables['securityheaderhistory'],
    tables['companyhistory'],
    output_dir=TEMP_DIR,
    verbose = True
)

print(f"Done! Saved to {final_path}")
# Out:
# [merge_histories][sec_concat] cols_left=43 cols_right=43 left_only=[] right_only=[] dtype_mismatch=[]
# [merge_histories][comp_concat] cols_left=49 cols_right=49 left_only=[] right_only=[] dtype_mismatch=[]
# Done! Saved to /content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data.parquet

# %%
from thesis_pkg.pipeline import load_tables, merge_histories, build_price_panel, attach_filings, add_final_returns, attach_ccm_links, attach_company_description
from pathlib import Path
import polars as pl

# 1. Config
BASE_DIR = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/parquet_data')
BASE_DIR2 = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/')
TEMP_DIR = BASE_DIR2 / 'derived_data'

final_path = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data.parquet')
final_path2 = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data_compdesc_added.parquet')

filenames = {
    'companydescription'
}

# 2. Load
# tables = load_tables([BASE_DIR], wanted={"sfz_dp_dly", "sfz_del", "companyhistory", ...})
tables = load_tables([BASE_DIR], wanted=filenames)

final_lf = pl.scan_parquet(final_path)
final_lf = attach_company_description(final_lf, tables['companydescription'])
final_lf.sink_parquet(final_path2, compression='zstd')

# %%
from thesis_pkg.pipeline import sink_exact_firm_sample_from_parquet
from pathlib import Path
import polars as pl

BASE_DIR2 = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/')
TEMP_DIR = BASE_DIR2 / 'derived_data'
sample_frac = 0.01
sample_path = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data')
sample_seed = 123
final_path = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data_compdesc_added.parquet')

sample_frac = 0.1
sample_seed = 42

sample_path = final_path.with_name(f"{final_path.stem}.sample_{int(sample_frac*100)}pct_seed{sample_seed}_compdesc.parquet")
firm_list_path = final_path.with_name(f"{final_path.stem}.firms_{int(sample_frac*100)}pct_seed{sample_seed}_compdesc.parquet")

out = sink_exact_firm_sample_from_parquet(
    full_source=final_path,
    sample_path=sample_path,
    firm_col="KYPERMNO",
    frac=sample_frac,
    seed=sample_seed,
    compression="zstd",
    save_firm_list_path=firm_list_path,
)

n = pl.scan_parquet(sample_path).select(pl.len()).collect().item()
n_firms = pl.scan_parquet(sample_path).select(pl.col("KYPERMNO").n_unique()).collect().item()
print({"rows": n, "unique_firms": n_firms, "path": str(out)})
# Out:
# {'rows': 6934534, 'unique_firms': 3041, 'path': '/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data_compdesc_added.sample_10pct_seed42_compdesc.parquet'}

# %%
sample_df = pl.read_parquet(sample_path)
print(sample_df.head(10))
# Out:
# shape: (10, 53)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬───┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ KYP ┆ CAL ┆ PRC ┆ RET ┆ RET ┆ TCA ┆ VOL ┆ BID ┆ ASK ┆ BID ┆ ASK ┆ NUM ┆ OPE ┆ dat ┆ DLS ┆ DLS ┆ DLP ┆ DLA ┆ DLR ┆ DLR ┆ FIN ┆ FIN ┆ FIN ┆ SRC ┆ FIL ┆ … ┆ LIN ┆ LIN ┆ LIN ┆ LIN ┆ is_ ┆ val ┆ lin ┆ lin ┆ KYG ┆ KYG ┆ lin ┆ HIS ┆ HCH ┆ HTP ┆ HEX ┆ HIS ┆ HCH ┆ HCI ┆ HSI ┆ HNA ┆ HGS ┆ CIK ┆ n_c ┆ HCI ┆ CIK │
# │ ERM ┆ DT  ┆ --- ┆ --- ┆ X   ┆ P   ┆ --- ┆ LO  ┆ HI  ┆ --- ┆ --- ┆ TRD ┆ NPR ┆ a_s ┆ TDT ┆ TCD ┆ RC  ┆ MT  ┆ ET  ┆ ETX ┆ AL_ ┆ AL_ ┆ AL_ ┆ TYP ┆ EDA ┆   ┆ KDT ┆ KEN ┆ KTY ┆ KPR ┆ can ┆ id_ ┆ k_r ┆ k_r ┆ VKE ┆ VKE ┆ k_q ┆ T_S ┆ GEN ┆ CI  ┆ CNT ┆ T_S ┆ GEN ┆ K   ┆ C   ┆ ICS ┆ UBI ┆ _de ┆ ik_ ┆ K_1 ┆ _fi │
# │ NO  ┆ --- ┆ f64 ┆ f64 ┆ --- ┆ --- ┆ f64 ┆ --- ┆ --- ┆ f64 ┆ f64 ┆ --- ┆ C   ┆ tat ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ RET ┆ RET ┆ PRC ┆ E_a ┆ TE_ ┆   ┆ --- ┆ DDT ┆ PE  ┆ IM  ┆ oni ┆ lin ┆ ank ┆ ank ┆ Y_c ┆ Y_f ┆ ual ┆ TAR ┆ DDT ┆ --- ┆ RY  ┆ TAR ┆ DDT ┆ --- ┆ --- ┆ --- ┆ ND  ┆ sc_ ┆ des ┆ 0   ┆ nal │
# │ --- ┆ dat ┆     ┆     ┆ f64 ┆ f64 ┆     ┆ f64 ┆ f64 ┆     ┆     ┆ i64 ┆ --- ┆ us  ┆ dat ┆ i32 ┆ f64 ┆ f64 ┆ f64 ┆ f64 ┆ --- ┆ X   ┆ --- ┆ ll  ┆ all ┆   ┆ dat ┆ --- ┆ --- ┆ --- ┆ cal ┆ k   ┆ _ba ┆ --- ┆ cm  ┆ ina ┆ ity ┆ T_D ┆ _SE ┆ str ┆ --- ┆ T_D ┆ _CO ┆ str ┆ i32 ┆ str ┆ --- ┆ 10  ┆ c_u ┆ --- ┆ --- │
# │ i32 ┆ e   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ f64 ┆ --- ┆ e   ┆     ┆     ┆     ┆     ┆     ┆ f64 ┆ --- ┆ f64 ┆ --- ┆ --- ┆   ┆ e   ┆ dat ┆ str ┆ str ┆ _li ┆ --- ┆ se  ┆ i32 ┆ --- ┆ l   ┆ _fl ┆ ATE ┆ C   ┆     ┆ str ┆ ATE ┆ MP  ┆     ┆     ┆     ┆ str ┆ --- ┆ niq ┆ str ┆ str │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ u64 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ f64 ┆     ┆ lis ┆ lis ┆   ┆     ┆ e   ┆     ┆     ┆ nk  ┆ boo ┆ --- ┆     ┆ i32 ┆ --- ┆ ag  ┆ _SE ┆ --- ┆     ┆     ┆ _CO ┆ --- ┆     ┆     ┆     ┆     ┆ str ┆ --- ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ t[s ┆ t[d ┆   ┆     ┆     ┆     ┆     ┆ --- ┆ l   ┆ i32 ┆     ┆     ┆ i32 ┆ --- ┆ C   ┆ dat ┆     ┆     ┆ MP  ┆ dat ┆     ┆     ┆     ┆     ┆     ┆ u32 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ tr] ┆ ate ┆   ┆     ┆     ┆     ┆     ┆ boo ┆     ┆     ┆     ┆     ┆     ┆ str ┆ --- ┆ e   ┆     ┆     ┆ --- ┆ e   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ]   ┆   ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆ dat ┆     ┆     ┆     ┆ dat ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e   ┆     ┆     ┆     ┆ e   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═══╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ 226 ┆ 199 ┆ 3.1 ┆ 0.0 ┆ 0.0 ┆ 144 ┆ 132 ┆ 3.1 ┆ 3.1 ┆ 3.0 ┆ 3.1 ┆ 2   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 0.0 ┆ 0.0 ┆ 3.1 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆ 25  ┆ 204 ┆ 204 ┆ 40. ┆ 5.0 ┆ 25  ┆ 25  ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 204 ┆ 204 ┆ 25  ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-0 ┆     ┆ 08  ┆ 08  ┆ 625 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 08  ┆ 08  ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 2   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.1 ┆ 0.0 ┆ 0.0 ┆ 144 ┆ 850 ┆ 3.0 ┆ 3.1 ┆ 3.0 ┆ 3.1 ┆ 2   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 0.0 ┆ 0.0 ┆ 3.1 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆ 25  ┆     ┆     ┆ 40. ┆ .0  ┆     ┆ 25  ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆     ┆     ┆ 25  ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-0 ┆     ┆     ┆     ┆ 625 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 3   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.0 ┆ -0. ┆ -0. ┆ 138 ┆ 100 ┆ 3.0 ┆ 3.0 ┆ 3.0 ┆ 3.1 ┆ 1   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ -0. ┆ -0. ┆ 3.0 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆     ┆ 04  ┆ 04  ┆ 63. ┆ .0  ┆     ┆     ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 04  ┆ 04  ┆     ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-0 ┆     ┆     ┆     ┆ 0   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 4   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.1 ┆ 0.0 ┆ 0.0 ┆ 144 ┆ 270 ┆ 3.0 ┆ 3.1 ┆ 3.0 ┆ 3.1 ┆ 3   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 0.0 ┆ 0.0 ┆ 3.1 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆ 25  ┆ 416 ┆ 416 ┆ 40. ┆ 0.0 ┆     ┆ 25  ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 416 ┆ 416 ┆ 25  ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-0 ┆     ┆ 67  ┆ 67  ┆ 625 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 67  ┆ 67  ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.0 ┆ -0. ┆ -0. ┆ 141 ┆ 467 ┆ 3.0 ┆ 3.1 ┆ 3.0 ┆ 3.1 ┆ 4   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ -0. ┆ -0. ┆ 3.0 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆ 625 ┆ 02  ┆ 02  ┆ 51. ┆ 9.0 ┆     ┆ 25  ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 02  ┆ 02  ┆ 625 ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-0 ┆     ┆     ┆     ┆ 812 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 8   ┆     ┆     ┆     ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.0 ┆ -0. ┆ -0. ┆ 138 ┆ 400 ┆ 3.0 ┆ 3.0 ┆ 3.0 ┆ 3.1 ┆ 1   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ -0. ┆ -0. ┆ 3.0 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆     ┆ 020 ┆ 020 ┆ 63. ┆ 0.0 ┆     ┆     ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 020 ┆ 020 ┆     ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-0 ┆     ┆ 408 ┆ 408 ┆ 0   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 408 ┆ 408 ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.1 ┆ 0.0 ┆ 0.0 ┆ 144 ┆ 350 ┆ 3.0 ┆ 3.1 ┆ 3.0 ┆ 3.1 ┆ 2   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 0.0 ┆ 0.0 ┆ 3.1 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆ 25  ┆ 416 ┆ 416 ┆ 40. ┆ .0  ┆     ┆ 25  ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 416 ┆ 416 ┆ 25  ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-1 ┆     ┆ 67  ┆ 67  ┆ 625 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 67  ┆ 67  ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 0   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.0 ┆ -0. ┆ -0. ┆ 138 ┆ 510 ┆ 3.0 ┆ 3.0 ┆ 3.0 ┆ 3.1 ┆ 4   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ -0. ┆ -0. ┆ 3.0 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆     ┆ 04  ┆ 04  ┆ 63. ┆ 0.0 ┆     ┆     ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 04  ┆ 04  ┆     ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-1 ┆     ┆     ┆     ┆ 0   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 1   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.0 ┆ 0.0 ┆ 0.0 ┆ 138 ┆ 446 ┆ 3.0 ┆ 3.0 ┆ 3.0 ┆ 3.1 ┆ 4   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 0.0 ┆ 0.0 ┆ 3.0 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆     ┆     ┆     ┆ 63. ┆ 0.0 ┆     ┆     ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆     ┆     ┆     ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-1 ┆     ┆     ┆     ┆ 0   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 2   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ 226 ┆ 199 ┆ 3.1 ┆ 0.0 ┆ 0.0 ┆ 144 ┆ 111 ┆ 3.0 ┆ 3.1 ┆ 3.0 ┆ 3.1 ┆ 2   ┆ nul ┆ 615 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 0.0 ┆ 0.0 ┆ 3.1 ┆ nul ┆ nul ┆ … ┆ 198 ┆ 199 ┆ LU  ┆ P   ┆ tru ┆ tru ┆ 2   ┆ 2   ┆ 293 ┆ 293 ┆ can ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 000 ┆ 1   ┆ nul ┆ 000 │
# │ 81  ┆ 0-0 ┆ 25  ┆ 416 ┆ 416 ┆ 40. ┆ 6.0 ┆     ┆ 25  ┆     ┆ 25  ┆     ┆ l   ┆ 823 ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 416 ┆ 416 ┆ 25  ┆ l   ┆ l   ┆   ┆ 3-0 ┆ 6-0 ┆     ┆     ┆ e   ┆ e   ┆     ┆     ┆ 0   ┆ 0   ┆ oni ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 035 ┆     ┆ l   ┆ 035 │
# │     ┆ 1-1 ┆     ┆ 67  ┆ 67  ┆ 625 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 67  ┆ 67  ┆     ┆     ┆     ┆   ┆ 1-3 ┆ 2-2 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ cal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 679 ┆     ┆     ┆ 679 │
# │     ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆ 1   ┆ 9   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 9   ┆     ┆     ┆ 9   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ima ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ry_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oth ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ er  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴───┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %%
import polars as pl
from thesis_pkg.pipeline import DataStatus
sample_df = pl.read_parquet(sample_path)

def decode_data_status(lf: pl.LazyFrame | pl.DataFrame) -> pl.LazyFrame | pl.DataFrame:
    """
    Expands the 'data_status' bitmask column into individual boolean columns
    for quick interpretation.
    """
    # Generate a polars expression for each flag in the Enum
    # Logic: (column & flag_value) == flag_value
    flag_exprs = [
        (
            (pl.col("data_status").cast(pl.UInt64) & flag.value) == flag.value
        ).alias(f"status_{flag.name.lower()}")
        for flag in DataStatus
        if flag.value > 0  # Skip DataStatus.NONE
    ]

    return lf.with_columns(flag_exprs)

# Usage Example assuming 'df' is your current dataframe
df_decoded = decode_data_status(sample_df)
print(df_decoded.select(pl.col("^status_.*$")).head())
# Out:
# shape: (5, 20)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta ┆ sta │
# │ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus ┆ tus │
# │ _ha ┆ _ha ┆ _ha ┆ _ha ┆ _ha ┆ _ha ┆ _ha ┆ _co ┆ _co ┆ _co ┆ _co ┆ _co ┆ _co ┆ _se ┆ _se ┆ _se ┆ _se ┆ _se ┆ _se ┆ _ha │
# │ s_r ┆ s_b ┆ s_r ┆ s_p ┆ s_d ┆ s_d ┆ s_d ┆ mph ┆ mph ┆ mph ┆ mph ┆ mph ┆ mph ┆ chi ┆ chi ┆ chi ┆ chi ┆ chi ┆ chi ┆ s_c │
# │ et  ┆ idl ┆ etx ┆ rc  ┆ lre ┆ lre ┆ lpr ┆ ist ┆ ist ┆ ist ┆ ist ┆ ist ┆ ist ┆ st_ ┆ st_ ┆ st_ ┆ st_ ┆ st_ ┆ st_ ┆ omp │
# │ --- ┆ o   ┆ --- ┆ --- ┆ t   ┆ tx  ┆ c   ┆ _ca ┆ _at ┆ _ma ┆ _no ┆ _va ┆ _st ┆ can ┆ att ┆ mat ┆ no_ ┆ val ┆ sta ┆ _de │
# │ boo ┆ --- ┆ boo ┆ boo ┆ --- ┆ --- ┆ --- ┆ n_a ┆ tem ┆ tch ┆ _ma ┆ lid ┆ ale ┆ _at ┆ emp ┆ che ┆ mat ┆ id  ┆ le  ┆ sc  │
# │ l   ┆ boo ┆ l   ┆ l   ┆ boo ┆ boo ┆ boo ┆ tte ┆ pte ┆ ed  ┆ tch ┆ --- ┆ --- ┆ tem ┆ ted ┆ d   ┆ ch  ┆ --- ┆ --- ┆ --- │
# │     ┆ l   ┆     ┆     ┆ l   ┆ l   ┆ l   ┆ mpt ┆ d   ┆ --- ┆ --- ┆ boo ┆ boo ┆ pt  ┆ --- ┆ --- ┆ --- ┆ boo ┆ boo ┆ boo │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ --- ┆ --- ┆ boo ┆ boo ┆ l   ┆ l   ┆ --- ┆ boo ┆ boo ┆ boo ┆ l   ┆ l   ┆ l   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ boo ┆ boo ┆ l   ┆ l   ┆     ┆     ┆ boo ┆ l   ┆ l   ┆ l   ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆ l   ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ tru ┆ tru ┆ tru ┆ tru ┆ fal ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru │
# │ e   ┆ e   ┆ e   ┆ e   ┆ se  ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   │
# │ tru ┆ tru ┆ tru ┆ tru ┆ fal ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru │
# │ e   ┆ e   ┆ e   ┆ e   ┆ se  ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   │
# │ tru ┆ tru ┆ tru ┆ tru ┆ fal ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru │
# │ e   ┆ e   ┆ e   ┆ e   ┆ se  ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   │
# │ tru ┆ tru ┆ tru ┆ tru ┆ fal ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru │
# │ e   ┆ e   ┆ e   ┆ e   ┆ se  ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   │
# │ tru ┆ tru ┆ tru ┆ tru ┆ fal ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru ┆ tru ┆ fal ┆ tru ┆ fal ┆ fal ┆ tru │
# │ e   ┆ e   ┆ e   ┆ e   ┆ se  ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   ┆ e   ┆ se  ┆ e   ┆ se  ┆ se  ┆ e   │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %%
from __future__ import annotations

from dataclasses import dataclass
from pathlib import Path
import polars as pl


# Keep in sync with your pipeline
STATUS_DTYPE = pl.UInt64

# Paste/import your DataStatus IntFlag here if you want exact ints;
# otherwise you can pass raw integers to has_flag().
# Example:
# from pipeline import DataStatus

def has_flag(status: pl.Expr, flag_int: int) -> pl.Expr:
    return (status.cast(STATUS_DTYPE) & pl.lit(flag_int, dtype=STATUS_DTYPE)) != 0


@dataclass(frozen=True)
class DiagnosticsConfig:
    required_cols: tuple[str, ...] = (
        "KYPERMNO", "CALDT", "data_status", "KYGVKEY_final"
    )
    cik_cols: tuple[str, ...] = (
        "HCIK", "HCIK_10", "CIK_desc_10", "n_cik_desc_uniq", "CIK_final"
    )


def run_pipeline_diagnostics(
    source: str | Path | pl.LazyFrame,
    *,
    cfg: DiagnosticsConfig = DiagnosticsConfig(),
    # Provide these as integers: int(DataStatus.HAS_RET), etc.
    flags: dict[str, int] | None = None,
) -> dict[str, pl.DataFrame]:
    """
    Compute diagnostic tables for a pipeline output.
    Returns a dict of DataFrames keyed by diagnostic name.
    """
    lf = source if isinstance(source, pl.LazyFrame) else pl.scan_parquet(str(source))

    schema = lf.collect_schema()
    missing_required = [c for c in cfg.required_cols if c not in schema]
    if missing_required:
        raise ValueError(f"Missing required columns: {missing_required}")

    out: dict[str, pl.DataFrame] = {}

    # ---- 1) Schema overview
    out["schema"] = pl.DataFrame(
        {"column": list(schema.keys()), "dtype": [str(schema[k]) for k in schema.keys()]}
    )

    # ---- 2) Key health: duplicates/nulls
    out["key_health"] = (
        lf.select([
            pl.len().alias("n_rows"),
            pl.col("KYPERMNO").is_null().sum().alias("n_null_permno"),
            pl.col("CALDT").is_null().sum().alias("n_null_caldt"),
            pl.col("KYGVKEY_final").is_null().sum().alias("n_null_gvkey_final"),
        ]).collect()
    )

    out["duplicate_rows_by_key"] = (
        lf.group_by(["KYPERMNO", "CALDT"])
          .agg(pl.len().alias("n"))
          .filter(pl.col("n") > 1)
          .select([
              pl.len().alias("n_duplicate_keys"),
              pl.col("n").sum().alias("n_rows_in_duplicate_keys"),
              pl.col("n").max().alias("max_dupe_multiplicity"),
          ])
          .collect()
    )

    # ---- 3) Bitmask ↔ column spot-check consistency (if flags provided)
    if flags is not None:
        status = pl.col("data_status").cast(STATUS_DTYPE)

        checks = []

        def add_flag_check(flag_name: str, col: str):
            if col not in schema:
                return
            f = flags[flag_name]
            checks.extend([
                (has_flag(status, f) & pl.col(col).is_null()).sum().alias(f"{flag_name}_set_but_{col}_null"),
                ((~has_flag(status, f)) & pl.col(col).is_not_null()).sum().alias(f"{flag_name}_notset_but_{col}_nonnull"),
            ])

        # Common ones
        for nm, col in [
            ("HAS_RET", "RET"),
            ("HAS_RETX", "RETX"),
            ("HAS_PRC", "PRC"),
            ("HAS_DLRET", "DLRET"),
            ("HAS_DLRETX", "DLRETX"),
            ("HAS_DLPRC", "DLPRC"),
        ]:
            if nm in flags:
                add_flag_check(nm, col)

        # History matched flags vs their join outputs (if present)
        if "SECHIST_MATCHED" in flags and "HIST_START_DATE_SEC" in schema:
            checks.append(
                (has_flag(status, flags["SECHIST_MATCHED"]) & pl.col("HIST_START_DATE_SEC").is_null())
                .sum().alias("SECHIST_MATCHED_set_but_HIST_START_DATE_SEC_null")
            )

        if "COMPHIST_MATCHED" in flags and "HIST_START_DATE_COMP" in schema:
            checks.append(
                (has_flag(status, flags["COMPHIST_MATCHED"]) & pl.col("HIST_START_DATE_COMP").is_null())
                .sum().alias("COMPHIST_MATCHED_set_but_HIST_START_DATE_COMP_null")
            )

        out["flag_column_consistency"] = lf.select([pl.len().alias("n_rows"), *checks]).collect()

    # ---- 4) CIK quality + coverage (only if CIK_final exists)
    if "CIK_final" in schema:
        cik = pl.col("CIK_final").cast(pl.Utf8, strict=False)
        is_10_digits = cik.str.contains(r"^\d{10}$")
        is_all_zeros = cik == "0000000000"

        out["cik_quality"] = (
            lf.select([
                pl.len().alias("n_rows"),
                cik.is_null().sum().alias("n_cik_final_null"),
                (~is_10_digits & cik.is_not_null()).sum().alias("n_cik_final_bad_format"),
                is_all_zeros.sum().alias("n_cik_final_all_zeros"),
                (is_10_digits & ~is_all_zeros).sum().alias("n_cik_final_valid_10d_nonzero"),
            ]).collect()
        )

    # ---- 5) Incremental gain: filled by desc when HCIK missing (if those columns exist)
    if "CIK_desc_10" in schema:
        hcik10 = pl.col("HCIK_10") if "HCIK_10" in schema else pl.lit(None, dtype=pl.Utf8)
        out["cik_source_gain"] = (
            lf.select([
                pl.len().alias("n_rows"),
                hcik10.is_not_null().sum().alias("n_hcik10_nonnull"),
                pl.col("CIK_desc_10").is_not_null().sum().alias("n_desc10_nonnull"),
                pl.col("CIK_final").is_not_null().sum().alias("n_cik_final_nonnull") if "CIK_final" in schema else pl.lit(None).alias("n_cik_final_nonnull"),
                (hcik10.is_null() & pl.col("CIK_desc_10").is_not_null()).sum().alias("n_filled_by_desc_when_hcik_missing"),
            ]).collect()
        )

    # ---- 6) Conflicts: HCIK_10 vs CIK_desc_10
    if "HCIK_10" in schema and "CIK_desc_10" in schema:
        both = pl.col("HCIK_10").is_not_null() & pl.col("CIK_desc_10").is_not_null()
        mismatch = both & (pl.col("HCIK_10") != pl.col("CIK_desc_10"))

        out["cik_conflicts"] = (
            lf.select([
                pl.len().alias("n_rows"),
                both.sum().alias("n_rows_both_sources"),
                mismatch.sum().alias("n_rows_mismatch"),
                (mismatch / pl.when(both.sum() > 0).then(both.sum()).otherwise(1)).alias("mismatch_rate_given_both"),
            ]).collect()
        )

        if "n_cik_desc_uniq" in schema:
            out["cik_conflicts_by_ambiguity"] = (
                lf.with_columns([
                    pl.when(pl.col("n_cik_desc_uniq").is_null()).then(pl.lit("unknown"))
                      .when(pl.col("n_cik_desc_uniq") <= 1).then(pl.lit("uniq<=1"))
                      .otherwise(pl.lit("uniq>1"))
                      .alias("desc_ambiguity_bucket"),
                    mismatch.alias("is_mismatch"),
                    both.alias("has_both"),
                ])
                .group_by("desc_ambiguity_bucket")
                .agg([
                    pl.len().alias("n_rows"),
                    pl.col("has_both").sum().alias("n_has_both"),
                    pl.col("is_mismatch").sum().alias("n_mismatch"),
                ])
                .collect()
            )

    # ---- 7) Ambiguous mappings impact (top GVKEYs)
    if "n_cik_desc_uniq" in schema:
        out["ambiguous_gvkeys_top"] = (
            lf.filter(pl.col("n_cik_desc_uniq") > 1)
              .group_by("KYGVKEY_final")
              .agg([
                  pl.len().alias("n_panel_rows"),
                  pl.max("n_cik_desc_uniq").alias("n_cik_desc_uniq"),
                  pl.col("CIK_desc_10").n_unique().alias("n_desc_10_seen_in_panel") if "CIK_desc_10" in schema else pl.lit(None).alias("n_desc_10_seen_in_panel"),
              ])
              .sort(["n_panel_rows", "n_cik_desc_uniq"], descending=True)
              .head(50)
              .collect()
        )

    return out


# Convenience: build flags dict from your IntFlag class
def build_flags_dict(DataStatus_cls) -> dict[str, int]:
    return {name: int(getattr(DataStatus_cls, name)) for name in dir(DataStatus_cls) if name.isupper()}

from pathlib import Path
import polars as pl


final_path_sample = Path('/content/drive/MyDrive/Data_LM/CRSP_Compustat_data/derived_data/final_flagged_data_compdesc_added.parquet')

# If you have DataStatus available:
# from pipeline import DataStatus
# flags = build_flags_dict(DataStatus)

# Otherwise, skip flags=None for now
diagnostics = run_pipeline_diagnostics(final_path_sample, flags=None)

diagnostics["key_health"]
diagnostics["cik_quality"]
diagnostics.get("cik_source_gain")
diagnostics.get("cik_conflicts")
diagnostics.get("ambiguous_gvkeys_top")
# Out:
# shape: (0, 4)
# ┌───────────────┬──────────────┬─────────────────┬─────────────────────────┐
# │ KYGVKEY_final ┆ n_panel_rows ┆ n_cik_desc_uniq ┆ n_desc_10_seen_in_panel │
# │ ---           ┆ ---          ┆ ---             ┆ ---                     │
# │ i32           ┆ u32          ┆ u32             ┆ u32                     │
# ╞═══════════════╪══════════════╪═════════════════╪═════════════════════════╡
# └───────────────┴──────────────┴─────────────────┴─────────────────────────┘

# %%
diagnostics
# Out:
# {'schema': shape: (53, 2)
#  ┌──────────────────────┬──────────────┐
#  │ column               ┆ dtype        │
#  │ ---                  ┆ ---          │
#  │ str                  ┆ str          │
#  ╞══════════════════════╪══════════════╡
#  │ KYPERMNO             ┆ Int32        │
#  │ CALDT                ┆ Date         │
#  │ PRC                  ┆ Float64      │
#  │ RET                  ┆ Float64      │
#  │ RETX                 ┆ Float64      │
#  │ TCAP                 ┆ Float64      │
#  │ VOL                  ┆ Float64      │
#  │ BIDLO                ┆ Float64      │
#  │ ASKHI                ┆ Float64      │
#  │ BID                  ┆ Float64      │
#  │ ASK                  ┆ Float64      │
#  │ NUMTRD               ┆ Int64        │
#  │ OPENPRC              ┆ Float64      │
#  │ data_status          ┆ UInt64       │
#  │ DLSTDT               ┆ Date         │
#  │ DLSTCD               ┆ Int32        │
#  │ DLPRC                ┆ Float64      │
#  │ DLAMT                ┆ Float64      │
#  │ DLRET                ┆ Float64      │
#  │ DLRETX               ┆ Float64      │
#  │ FINAL_RET            ┆ Float64      │
#  │ FINAL_RETX           ┆ Float64      │
#  │ FINAL_PRC            ┆ Float64      │
#  │ SRCTYPE_all          ┆ List(String) │
#  │ FILEDATE_all         ┆ List(Date)   │
#  │ …                    ┆ …            │
#  │ LINKDT               ┆ Date         │
#  │ LINKENDDT            ┆ Date         │
#  │ LINKTYPE             ┆ String       │
#  │ LINKPRIM             ┆ String       │
#  │ is_canonical_link    ┆ Boolean      │
#  │ valid_link           ┆ Boolean      │
#  │ link_rank_base       ┆ Int32        │
#  │ link_rank            ┆ Int32        │
#  │ KYGVKEY_ccm          ┆ Int32        │
#  │ KYGVKEY_final        ┆ Int32        │
#  │ link_quality_flag    ┆ String       │
#  │ HIST_START_DATE_SEC  ┆ Date         │
#  │ HCHGENDDT_SEC        ┆ Date         │
#  │ HTPCI                ┆ String       │
#  │ HEXCNTRY             ┆ String       │
#  │ HIST_START_DATE_COMP ┆ Date         │
#  │ HCHGENDDT_COMP       ┆ Date         │
#  │ HCIK                 ┆ String       │
#  │ HSIC                 ┆ Int32        │
#  │ HNAICS               ┆ String       │
#  │ HGSUBIND             ┆ String       │
#  │ CIK_desc_10          ┆ String       │
#  │ n_cik_desc_uniq      ┆ UInt32       │
#  │ HCIK_10              ┆ String       │
#  │ CIK_final            ┆ String       │
#  └──────────────────────┴──────────────┘,
#  'key_health': shape: (1, 4)
#  ┌──────────┬───────────────┬──────────────┬────────────────────┐
#  │ n_rows   ┆ n_null_permno ┆ n_null_caldt ┆ n_null_gvkey_final │
#  │ ---      ┆ ---           ┆ ---          ┆ ---                │
#  │ u32      ┆ u32           ┆ u32          ┆ u32                │
#  ╞══════════╪═══════════════╪══════════════╪════════════════════╡
#  │ 67623439 ┆ 0             ┆ 0            ┆ 963575             │
#  └──────────┴───────────────┴──────────────┴────────────────────┘,
#  'duplicate_rows_by_key': shape: (1, 3)
#  ┌──────────────────┬──────────────────────────┬───────────────────────┐
#  │ n_duplicate_keys ┆ n_rows_in_duplicate_keys ┆ max_dupe_multiplicity │
#  │ ---              ┆ ---                      ┆ ---                   │
#  │ u32              ┆ u32                      ┆ u32                   │
#  ╞══════════════════╪══════════════════════════╪═══════════════════════╡
#  │ 0                ┆ 0                        ┆ null                  │
#  └──────────────────┴──────────────────────────┴───────────────────────┘,
#  'cik_quality': shape: (1, 5)
#  ┌──────────┬──────────────────┬──────────────────────┬──────────────────────┬──────────────────────┐
#  │ n_rows   ┆ n_cik_final_null ┆ n_cik_final_bad_form ┆ n_cik_final_all_zero ┆ n_cik_final_valid_10 │
#  │ ---      ┆ ---              ┆ at                   ┆ s                    ┆ d_nonzero            │
#  │ u32      ┆ u32              ┆ ---                  ┆ ---                  ┆ ---                  │
#  │          ┆                  ┆ u32                  ┆ u32                  ┆ u32                  │
#  ╞══════════╪══════════════════╪══════════════════════╪══════════════════════╪══════════════════════╡
#  │ 67623439 ┆ 10152191         ┆ 0                    ┆ 0                    ┆ 57471248             │
#  └──────────┴──────────────────┴──────────────────────┴──────────────────────┴──────────────────────┘,
#  'cik_source_gain': shape: (1, 5)
#  ┌──────────┬──────────────────┬──────────────────┬─────────────────────┬───────────────────────────┐
#  │ n_rows   ┆ n_hcik10_nonnull ┆ n_desc10_nonnull ┆ n_cik_final_nonnull ┆ n_filled_by_desc_when_hci │
#  │ ---      ┆ ---              ┆ ---              ┆ ---                 ┆ k_mis…                    │
#  │ u32      ┆ u32              ┆ u32              ┆ u32                 ┆ ---                       │
#  │          ┆                  ┆                  ┆                     ┆ u32                       │
#  ╞══════════╪══════════════════╪══════════════════╪═════════════════════╪═══════════════════════════╡
#  │ 67623439 ┆ 25784028         ┆ 56833509         ┆ 57471248            ┆ 31687220                  │
#  └──────────┴──────────────────┴──────────────────┴─────────────────────┴───────────────────────────┘,
#  'cik_conflicts': shape: (67_623_439, 4)
#  ┌──────────┬─────────────────────┬─────────────────┬──────────────────────────┐
#  │ n_rows   ┆ n_rows_both_sources ┆ n_rows_mismatch ┆ mismatch_rate_given_both │
#  │ ---      ┆ ---                 ┆ ---             ┆ ---                      │
#  │ u32      ┆ u32                 ┆ u32             ┆ f64                      │
#  ╞══════════╪═════════════════════╪═════════════════╪══════════════════════════╡
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ …        ┆ …                   ┆ …               ┆ …                        │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  │ 67623439 ┆ 25146289            ┆ 703923          ┆ 0.0                      │
#  └──────────┴─────────────────────┴─────────────────┴──────────────────────────┘,
#  'cik_conflicts_by_ambiguity': shape: (2, 4)
#  ┌───────────────────────┬──────────┬────────────┬────────────┐
#  │ desc_ambiguity_bucket ┆ n_rows   ┆ n_has_both ┆ n_mismatch │
#  │ ---                   ┆ ---      ┆ ---        ┆ ---        │
#  │ str                   ┆ u32      ┆ u32        ┆ u32        │
#  ╞═══════════════════════╪══════════╪════════════╪════════════╡
#  │ unknown               ┆ 963575   ┆ 0          ┆ 0          │
#  │ uniq<=1               ┆ 66659864 ┆ 25146289   ┆ 703923     │
#  └───────────────────────┴──────────┴────────────┴────────────┘,
#  'ambiguous_gvkeys_top': shape: (0, 4)
#  ┌───────────────┬──────────────┬─────────────────┬─────────────────────────┐
#  │ KYGVKEY_final ┆ n_panel_rows ┆ n_cik_desc_uniq ┆ n_desc_10_seen_in_panel │
#  │ ---           ┆ ---          ┆ ---             ┆ ---                     │
#  │ i32           ┆ u32          ┆ u32             ┆ u32                     │
#  ╞═══════════════╪══════════════╪═════════════════╪═════════════════════════╡
#  └───────────────┴──────────────┴─────────────────┴─────────────────────────┘}

# %%
import polars as pl
import os
import glob
import time

# --- Configuration ---
input_folder = "/content/drive/My Drive/Data_LM/parquet_data/_year_merged/"
output_folder = "/content/drive/My Drive/Data_LM/parquet_data/"
output_filename = "filings_metadata_1993_2024_LIGHT.parquet"
output_path = os.path.join(output_folder, output_filename)

# --- 1. Verification Phase ---
print("--- Phase 1: Verifying Individual Year Files ---")

# Find all yearly parquet files
parquet_files = sorted(glob.glob(os.path.join(input_folder, "*.parquet")))
valid_files = []
total_rows_detected = 0

if not parquet_files:
    print(f"CRITICAL: No parquet files found in {input_folder}")
    print("Please check if the folder path is correct.")
else:
    print(f"{'Year':<10} | {'Rows':<10} | {'Size (MB)':<10} | {'Status'}")
    print("-" * 55)

    for f_path in parquet_files:
        filename = os.path.basename(f_path)
        file_size_mb = os.path.getsize(f_path) / (1024 * 1024)

        try:
            # Create a LazyFrame (does not read data yet)
            lf = pl.scan_parquet(f_path)

            # Robust Check: Get columns as a simple list of strings
            # This works on virtually all Polars versions
            columns = lf.columns

            # Quick row count (reads metadata only)
            row_count = lf.select(pl.len()).collect().item()

            if 'full_text' not in columns:
                status = "WARN: No Text"
                # Still add to valid if you want metadata, but flag it
                valid_files.append(f_path)
            elif 'cik' not in columns:
                status = "ERR: No CIK"
            elif row_count == 0:
                status = "EMPTY"
            else:
                status = "OK"
                valid_files.append(f_path)
                total_rows_detected += row_count

            print(f"{filename[:4]:<10} | {row_count:<10,} | {file_size_mb:<10.2f} | {status}")

        except Exception as e:
            # Catch specific errors to avoid crashing the whole loop
            print(f"{filename[:4]:<10} | {'Error':<10} | {file_size_mb:<10.2f} | ERROR: {e}")

    print("-" * 55)
    print(f"Total valid files: {len(valid_files)}")
    print(f"Total records found: {total_rows_detected:,}")


# --- 2. Creation of Light Dataset (Metadata Only) ---
print("\n--- Phase 2: Creating Light Dataset (Excluding Full Text) ---")

if not valid_files:
    print("No valid files to process. Exiting.")
else:
    start_time = time.time()
    try:
        # Lazy load all valid files
        lf_all = pl.scan_parquet(valid_files)

        # Drop 'full_text' so we never load the heavy data into RAM
        # If 'full_text' is missing in some files (warn above), select only existing cols
        available_cols = lf_all.columns
        cols_to_keep = [c for c in available_cols if c != 'full_text']

        lf_light = lf_all.select(cols_to_keep)

        # Sort for cleanliness
        if "filing_date" in cols_to_keep and "cik" in cols_to_keep:
            lf_light = lf_light.sort(["filing_date", "cik"])

        print(f"Streaming columns {cols_to_keep} to {output_filename}...")

        # Write to disk
        lf_light.sink_parquet(output_path, compression='zstd')

        end_time = time.time()
        final_size_mb = os.path.getsize(output_path) / (1024 * 1024)

        print(f"SUCCESS: Light dataset created!")
        print(f"Time: {end_time - start_time:.2f}s")
        print(f"Size: {final_size_mb:.2f} MB")

        # --- Final Sanity Check ---
        print("\n--- Final Check (First 5 rows) ---")
        print(pl.read_parquet(output_path, n_rows=5))

    except Exception as e:
        print(f"CRITICAL ERROR during final merge: {e}")
# Out:
# --- Phase 1: Verifying Individual Year Files ---
# Year       | Rows       | Size (MB)  | Status
# -------------------------------------------------------
# /tmp/ipython-input-3635182866.py:37: PerformanceWarning: Determining the column names of a LazyFrame requires resolving its schema, which is a potentially expensive operation. Use `LazyFrame.collect_schema().names()` to get the column names without this warning.
#   columns = lf.columns
# 1993       | 13         | 0.34       | OK
# 1994       | 9,752      | 306.95     | OK
# 1995       | 21,880     | 520.23     | OK
# 1996       | 44,531     | 1030.85    | OK
# 1997       | 55,484     | 1546.29    | OK
# 1998       | 55,735     | 1705.16    | OK
# 1999       | 56,330     | 1737.04    | OK
# 2000       | 59,419     | 1773.69    | OK
# 2001       | 56,873     | 1728.94    | OK
# 2002       | 54,220     | 1805.77    | OK
# 2003       | 50,399     | 1898.30    | OK
# 2004       | 49,821     | 1964.38    | OK
# 2005       | 50,717     | 2011.29    | OK
# 2006       | 49,032     | 2051.16    | OK
# 2007       | 47,990     | 2076.95    | OK
# 2008       | 47,216     | 2033.59    | OK
# 2009       | 42,359     | 2007.85    | OK
# 2010       | 40,024     | 1935.65    | OK
# 2011       | 40,087     | 1842.38    | OK
# 2012       | 37,498     | 1774.04    | OK
# 2013       | 34,998     | 1722.52    | OK
# 2014       | 33,993     | 1741.05    | OK
# 2015       | 32,539     | 1726.02    | OK
# 2016       | 30,286     | 1667.91    | OK
# 2017       | 28,755     | 1633.97    | OK
# 2018       | 28,017     | 1680.83    | OK
# 2019       | 27,014     | 1559.19    | OK
# 2020       | 26,184     | 1536.59    | OK
# 2021       | 29,320     | 1657.70    | OK
# 2022       | 30,151     | 1696.69    | OK
# 2023       | 27,857     | 1630.36    | OK
# 2024       | 26,014     | 1548.27    | OK
# -------------------------------------------------------
# Total valid files: 32
# Total records found: 1,224,508
#
# --- Phase 2: Creating Light Dataset (Excluding Full Text) ---
# Streaming columns ['doc_id', 'cik', 'cik_10', 'accession_number', 'accession_nodash', 'filing_date', 'filing_date_header', 'file_date_filename', 'document_type_filename', 'filename', 'zip_member_path', 'filename_parse_ok', 'cik_header_primary', 'ciks_header_secondary', 'accession_header', 'cik_conflict', 'accession_conflict'] to filings_metadata_1993_2024_LIGHT.parquet...
# /tmp/ipython-input-3635182866.py:79: PerformanceWarning: Determining the column names of a LazyFrame requires resolving its schema, which is a potentially expensive operation. Use `LazyFrame.collect_schema().names()` to get the column names without this warning.
#   available_cols = lf_all.columns

# %%
import os
import re
import polars as pl
import shutil
import gc  # Garbage collection
from google.colab import drive

# --- Configuration ---
drive.mount('/content/drive', force_remount=True)
drive_zip_folder = "/content/drive/My Drive/Data_LM/Zip_Files/"
drive_parquet_folder = "/content/drive/My Drive/Data_LM/parquet_data/"

# This will be the single final file
final_output_file = "/content/drive/My Drive/Data_LM/parquet_data/all_filings_1993_2024_combined.parquet"

colab_temp_zip = "/tmp/data.zip"
colab_extract_path = "/tmp/extracted_data/"

# Batch size: Number of files to hold in RAM before writing to disk
BATCH_SIZE = 2000

# Ensure base output folder exists
os.makedirs(drive_parquet_folder, exist_ok=True)

# --- Compile Regex Patterns ---
header_search_limit = 5000
cik_pattern_header = re.compile(r"CENTRAL INDEX KEY:\s*(\d+)")
date_pattern_header = re.compile(r"FILED AS OF DATE:\s*(\d{8})")
accession_pattern_header = re.compile(r"ACCESSION NUMBER:\s*([\d-]+)")

filename_pattern = re.compile(
    r"(\d{8})_"          # 1: Date (YYYYMMDD)
    r"([^_]+)_"          # 2: Type
    r"edgar_data_"
    r"(\d+)_"            # 3: CIK
    r"([\d-]+)"          # 4: Accession Number
    r"\.txt",
    re.IGNORECASE
)

def save_batch(data, year, batch_idx, output_folder):
    """Helper to save a batch of data to parquet."""
    if not data:
        return

    parquet_filename = f"{year}_batch_{batch_idx:04d}.parquet"
    output_path = os.path.join(output_folder, parquet_filename)

    schema = {
        'filename': pl.Utf8,
        'cik': pl.Int64,
        'accession_number': pl.Utf8,
        'filing_date': pl.Utf8,
        'document_type': pl.Utf8,
        'cik_header_primary': pl.Utf8,
        'ciks_header_secondary': pl.List(pl.Utf8),
        'accession_header': pl.Utf8,
        'accession_filename': pl.Utf8,
        'filing_date_header': pl.Utf8,
        'filing_date_filename': pl.Utf8,
        'cik_conflict': pl.Boolean,
        'accession_conflict': pl.Boolean,
        'full_text': pl.Utf8
    }

    try:
        df = pl.DataFrame(data, schema=schema)
        # Convert date and save
        df = df.with_columns(
            pl.col("filing_date").str.strptime(pl.Date, "%Y%m%d", strict=False)
        )
        df.write_parquet(output_path, compression='zstd')
        print(f"  Saved batch {batch_idx} with {len(df)} records to {parquet_filename}")
    except Exception as e:
        print(f"  ERROR saving batch {batch_idx}: {e}")

# --- Processing Loop ---
years = range(1993, 2025)

for year in years:
    year_str = str(year)
    zip_filename = f"{year_str}.zip"
    source_zip_path = os.path.join(drive_zip_folder, zip_filename)

    # Create a specific folder for this year's parquets to keep things organized
    year_output_folder = os.path.join(drive_parquet_folder, year_str)
    os.makedirs(year_output_folder, exist_ok=True)

    print(f"\n--- Processing Year: {year_str} ---")

    if not os.path.exists(source_zip_path):
        print(f"SKIPPING: Zip file not found at {source_zip_path}")
        continue

    # 1. Copy and Extract
    try:
        if os.path.exists(colab_extract_path): shutil.rmtree(colab_extract_path)
        os.makedirs(colab_extract_path)

        print(f"Copying {zip_filename}...")
        shutil.copyfile(source_zip_path, colab_temp_zip)

        print(f"Extracting...")
        shutil.unpack_archive(colab_temp_zip, colab_extract_path, 'zip')

        # Remove zip immediately to free space
        os.remove(colab_temp_zip)
    except Exception as e:
        print(f"CRITICAL ERROR during setup for {year_str}: {e}")
        if os.path.exists(colab_temp_zip): os.remove(colab_temp_zip)
        continue

    # 2. Process Files
    print("Processing text files...")
    report_data = []
    batch_counter = 1

    # Walk files
    files_iterator = []
    for root, _, files in os.walk(colab_extract_path):
        for f in files:
            if f.lower().endswith(".txt"):
                files_iterator.append(os.path.join(root, f))

    total_files = len(files_iterator)
    print(f"Found {total_files} text files.")

    for i, file_path in enumerate(files_iterator):
        filename = os.path.basename(file_path)

        # --- Reset extraction variables ---
        header_ciks_str_list = []
        header_filing_date_str = None
        header_accession_str = None
        full_text = None
        filename_cik_int = None
        filename_accession_str = None
        filename_date_str = None
        filename_type_str = None
        cik_conflict_flag = False
        acc_conflict_flag = False

        # --- Filename Parsing ---
        fn_match = filename_pattern.match(filename)
        if fn_match:
            try:
                filename_date_str = fn_match.group(1)
                filename_type_str = fn_match.group(2)
                filename_cik_int = int(fn_match.group(3))
                filename_accession_str = fn_match.group(4)
            except:
                cik_conflict_flag = True
        else:
            cik_conflict_flag = True
            acc_conflict_flag = True

        # --- Content Parsing ---
        try:
            # Use errors='replace' to avoid losing data due to a few bad bytes
            with open(file_path, 'r', encoding='utf-8', errors='replace') as f:
                full_text = f.read()

            # Header extraction
            header_search_area = full_text[:header_search_limit]

            header_ciks = cik_pattern_header.findall(header_search_area)
            header_ciks_int_set = {int(c) for c in header_ciks if c.isdigit()}

            date_match = date_pattern_header.search(header_search_area)
            if date_match: header_filing_date_str = date_match.group(1)

            accession_match = accession_pattern_header.search(header_search_area)
            if accession_match: header_accession_str = accession_match.group(1)

            # --- Validation Logic ---
            if filename_cik_int and (filename_cik_int not in header_ciks_int_set) and header_ciks_int_set:
                cik_conflict_flag = True

            if filename_accession_str and header_accession_str and (filename_accession_str != header_accession_str):
                acc_conflict_flag = True

            # Prioritize Header values, fallback to filename
            final_accession = header_accession_str or filename_accession_str
            final_date = header_filing_date_str or filename_date_str
            primary_header_cik = header_ciks[0] if header_ciks else None
            secondary_ciks = header_ciks[1:] if len(header_ciks) > 1 else []

            # Append
            report_data.append({
                'filename': filename,
                'cik': filename_cik_int,
                'accession_number': final_accession,
                'filing_date': final_date,
                'document_type': filename_type_str,
                'cik_header_primary': primary_header_cik,
                'ciks_header_secondary': secondary_ciks,
                'accession_header': header_accession_str,
                'accession_filename': filename_accession_str,
                'filing_date_header': header_filing_date_str,
                'filing_date_filename': filename_date_str,
                'cik_conflict': cik_conflict_flag,
                'accession_conflict': acc_conflict_flag,
                'full_text': full_text
            })

        except Exception as e:
            print(f"Error processing {filename}: {e}")

        # --- Batch Save Trigger ---
        if len(report_data) >= BATCH_SIZE:
            save_batch(report_data, year_str, batch_counter, year_output_folder)
            report_data = [] # Clear RAM
            batch_counter += 1
            gc.collect() # Force cleanup

    # Save remaining files in the last batch
    if report_data:
        save_batch(report_data, year_str, batch_counter, year_output_folder)

    # Cleanup extracted folder for the year
    if os.path.exists(colab_extract_path): shutil.rmtree(colab_extract_path)
    gc.collect()

# --- 3. Merge All Batches into One File ---
print("\n--- Extraction Phase Complete. Starting Final Merge ---")
print(f"Scanning for batches in {drive_parquet_folder}...")

try:
    # glob pattern to find all parquet files in year subfolders (e.g., parquet_data/2009/*.parquet)
    files_pattern = os.path.join(drive_parquet_folder, "**", "*.parquet")
    print(files_pattern)

    # Lazy load all files
    lf = pl.scan_parquet(files_pattern)

    print(f"Streaming combined data to: {final_output_file}")

    # Sink to single file using streaming (does not load everything into RAM)
    lf.sink_parquet(final_output_file, compression='zstd')

    print("SUCCESS: Single merged file created!")
    print("You may now manually delete the year folders in 'parquet_data' if you wish to save space.")

except Exception as e:
    print(f"ERROR during final merge: {e}")
    print("Note: Your individual batch files are still safe in the 'parquet_data' subfolders.")

# %%
import os, glob, json, time, shutil
import pyarrow as pa
import pyarrow.parquet as pq

drive_root = "/content/drive/My Drive/Data_LM/parquet_data"
drive_out_dir = f"{drive_root}/_year_merged"
local_work = "/content/_merge_work"
os.makedirs(drive_out_dir, exist_ok=True)
os.makedirs(local_work, exist_ok=True)

checkpoint_path = f"{local_work}/done_years.json"
done = set(json.load(open(checkpoint_path))) if os.path.exists(checkpoint_path) else set()

def concat_parquets_arrow(in_files, out_path, batch_size=32_000, compression="zstd", compression_level=1):
    writer = None
    try:
        for i, f in enumerate(in_files, 1):
            pf = pq.ParquetFile(f)
            for batch in pf.iter_batches(batch_size=batch_size):
                tbl = pa.Table.from_batches([batch])
                if writer is None:
                    writer = pq.ParquetWriter(
                        out_path, tbl.schema,
                        compression=compression,
                        compression_level=compression_level if compression == "zstd" else None
                    )
                writer.write_table(tbl)

            # keep the frontend alive + visible progress
            print(f"  appended {i}/{len(in_files)}: {os.path.basename(f)}", flush=True)
            time.sleep(0.2)  # tiny pause helps the Drive mount not freak out
    finally:
        if writer is not None:
            writer.close()

# years = sorted([d for d in os.listdir(drive_root) if d.isdigit() and len(d) == 4])
years = range(1993,2025)
for y_num in years:
    y = str(y_num)
    out_drive = f"{drive_out_dir}/{y}.parquet"
    if y in done and os.path.exists(out_drive):
        print(f"[skip] {y}", flush=True)
        continue

    files = sorted(glob.glob(f"{drive_root}/{y}/*.parquet"))
    if not files:
        print(f"[warn] {y}: no files", flush=True)
        continue

    tmp_local = f"{local_work}/{y}.parquet"
    if os.path.exists(tmp_local):
        os.remove(tmp_local)

    print(f"[merge] {y}: {len(files)} files", flush=True)
    concat_parquets_arrow(files, tmp_local, batch_size=32_000, compression="zstd", compression_level=1)

    shutil.move(tmp_local, out_drive)
    done.add(y)
    with open(checkpoint_path, "w") as f:
        json.dump(sorted(done), f)

    print(f"[done] {y} -> {out_drive}", flush=True)
    time.sleep(2)  # bigger pause between years (Drive cooldown)

# %%
import os, glob, shutil
import polars as pl

drive_root = "/content/drive/My Drive/Data_LM/parquet_data"
final_on_drive = f"{drive_root}/all_filings_1993_2024_combined.parquet"

# IMPORTANT: write locally first (Drive mount can be slow/odd), then move
tmp_local = "/content/all_filings_1993_2024_combined.parquet"

# Only scan year-subfolders, so you never re-read your already-merged output file.
files = sorted(glob.glob(os.path.join(drive_root, "[0-9][0-9][0-9][0-9]", "*.parquet")))
files = [f for f in files if os.path.abspath(f) != os.path.abspath(final_on_drive)]

# Lower memory pressure during scan: no caching, low_memory scan, no parallelism
lf = pl.scan_parquet(
    files,
    cache=False,
    low_memory=True,
    parallel="none",
)

# Sanity-check the plan (it should be essentially Scan -> Sink)
print(lf.explain())

# Bound peak memory during write by forcing smaller row groups (critical for huge text fields)
lf.sink_parquet(
    tmp_local,
    compression="zstd",
    compression_level=3,
    statistics=False,
    row_group_size=10_000,        # go smaller (e.g. 10_000) if rows contain giant strings
    # data_pagesize = 1_048_576 # 1MB (this is also the documented default)
)

shutil.move(tmp_local, final_on_drive)
print("SUCCESS")

# %%
lf.collect()

# %%
final_output_file

# %%
files_pattern
